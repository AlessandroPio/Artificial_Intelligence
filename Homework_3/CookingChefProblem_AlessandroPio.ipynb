# %% [markdown]
# # The Cooking Chef Problem
#
# Consider the case where the agent is your personal Chef. In particular, the agent (the smiley on the map) wants to cook the eggs recipe according to your indication (scrambled or pudding).
#
# In order to cook the desired recipe, the agent must first collect the needed tools (the egg beater on the map). Then he must reach the stove (the frying pan or the oven on the map). Finally, he can cook.
#
# Note that there are two special interlinked cells (marked with the G) that allow the agent to go from one side of the map to the other. But to do so, the agent needs to express his will to go on the other side.
#
# Cells in (4, 2) and (9, 3) are the special gate ones. They allow the agent to go from one side of the map to another. Those two special cells are interlinked, but the agent needs to express his will to go on the other side.
#
# Since you are very hungry, it is fundamental that the agent cooks the eggs according to your taste (scrambled/pudding) as fast as he can without letting you wait for more than necessary.
#
# In order to apply optimal control techniques such as value iteration, you need to model the aforementioned scenario as an MDP. Recall that an MDP is defined as a tuple (S, A, P, R, γ), where:
#
# - **S**: The (finite) set of all possible states.
# - **A**: The (finite) set of all possible actions.
# - **P**: The transition function P: S x S x A -> [0,1], which maps (s',s,a) to P(s′|s,a), i.e., the probability of transitioning to state s′ ∈ S when taking action a ∈ A in state s ∈ S. Note that ∑{s' ∈ S} P(s'|s, a) = 1 for all s ∈ S, a ∈ A.
# - **R**: The reward function R : S x A x S -> *R*, which maps (s,a,s') to R(s,a,s′), i.e., the reward obtained when taking action a ∈ A in state s ∈ S and arriving at state s′ ∈ S.
# - **γ**: The discount factor which controls how important rewards are in the future.

# %% [markdown]
# ![Instance Image](Problem_image.png)
#
# ##### A particular instance of the cooking Chef problem. The goal is for the agent currently located in state (4, 3) to have a policy that always leads to cooking the eggs in location (1, 4) or (8, 4). Cells in (4, 2) and (9,3) are the special gate.
#
# ##### In the figure:
# • The agent is at (4, 3) (but it can start at any of the grid cells).
# • The agent needed cooking tools as the egg beater is in position (1, 3) and (8, 3).
# • There are two different final goals, displayed as the frying pan is in position (1, 4) and the oven in position (8, 4).
# • Cells in (4, 2) and (9, 3) are the special gate ones. They allow the agent to go from one side of the map to another. Those two special cells are interlinked, but the agent needs to express his will to go on the other side.
# • The agent is not able to move diagonally.
# • Walls are represented by thick black lines.
# • The agent cannot move through walls.
# • An episode will end when the agent successfully cooks the scrambled eggs (see the above description).

# %% [markdown]
# Now, considering the problem as a model-free scenario, provide a program (written in Python, possibly based on the labs) that can compute the optimal policy for this world by solely considering the pudding eggs scenario. Draw the computed policy in the grid by putting the optimal action in each cell. If multiple actions are possible, include the probability of each arrow. There may be multiple optimal policies; pick one to show it. Note that the model is not available for computation but must be encoded to be used as the "real-world" environment.
#
# Note that the enviroment is 'setted' in the following way
#
# ![Instance_Image](states.png)
#
#
#
#
#
# __Author__ : Alessandro Pio n.294417

# %% [markdown]
# # Imports

# %%
from itertools import zip_longest
import numpy as np
import random

try:
    from terminaltables import AsciiTable
except ImportError:
    print("No terminaltables library was found but there is no problem, the code could still run")

# %% [markdown]
# # Utilities functions
#
# I the following cell i provide some utilities functions
#
# - `get_optimal_policy(q_table, actions)`
# This function calculates the optimal policy based on the Q-table and the available actions. It iterates through each state, finds the action with the highest Q-value, and assigns it to the optimal policy for that state.
# - `get_optimal_policy_matrix(optimal_policy)`
# This function creates two policy matrices (4x4 grids) for displaying the optimal policy visually. It maps actions to arrows for better representation.
# - `get_info(beater_opt_pol, cook_opt_pol)`
# This function prints a tabular representation of the optimal policy for both taking the beater and cooking actions. It uses the AsciiTable library for better formatting.

# %%
def get_optimal_policy(q_table, actions):
    """
    Calculates the optimal policy based on the Q-table and the available actions.

    Parameters:
    - q_table (numpy.ndarray): Q-table containing Q-values for different actions and states.
    - actions (list): List of possible actions.

    Returns:
    - dict: Optimal policy mapping states to corresponding optimal actions.
    """
    
    optimal_policy = {}
        
    for state in range(1, 33): # starting from 1 to 32
        optimal_action = actions[np.argmax(q_table[state - 1])]
        optimal_policy[state] = optimal_action
    return optimal_policy 

def get_optimal_policy_matrix(optimal_policy):
    """
    Creates two policy matrices for visualizing the optimal policy.

    Parameters:
    - optimal_policy (dict): Optimal policy mapping states to corresponding optimal actions.

    Prints:
    - Two policy matrices displayed in the console.
    """
    
    mapped_actions = {
            "U": "↑",
            "D": "↓",
            "L": "←",
            "R": "→",
            "T": "⤴",
            "TR": "⇒",
            "TL": "⇒"
        }
    
    policy_matrix1 = np.zeros((4, 4), dtype='U2')
    policy_matrix2 = np.zeros((4, 4), dtype='U2')
         
    for state, action in optimal_policy.items():
        
        if state <= 16:
            if Environment.oven == state:
                policy_matrix1[(state - 1) // 4, (state - 1) % 4] = "C"
            else:
                policy_matrix1[(state - 1) // 4, (state - 1) % 4] = mapped_actions[action]
        else:
            if Environment.oven == state:
                policy_matrix2[(state - 17) // 4, (state - 17) % 4] = "C"
            else:
                policy_matrix2[(state - 17) // 4, (state - 17) % 4] = mapped_actions[action]
        
    print("Optimal Policy Matrix 1:")
    print(policy_matrix1)
        
    print("\nOptimal Policy Matrix 2:")
    print(policy_matrix2)
    
def get_info(beater_opt_pol, cook_opt_pol):
    """
    Prints a tabular representation of the optimal policy for taking the beater and cooking actions.

    Parameters:
    - beater_opt_pol (dict): Optimal policy mapping states to corresponding optimal actions for taking the beater.
    - cook_opt_pol (dict): Optimal policy mapping states to corresponding optimal actions for cooking.

    Prints:
    - A formatted table displaying the optimal policies for both actions.
    """
    
    data = [["STATE", "BEATER OPT POLICY", "COOK OPT POLICY"]]

    keys_beater, values_beater = list(beater_opt_pol.keys()), list(cook_opt_pol.values())
    keys_cook, values_cook = list(beater_opt_pol.keys()), list(cook_opt_pol.values())
    
    for num, (key_b, value_b, key_c, value_c) in enumerate(zip_longest(keys_beater, values_beater, keys_cook, values_cook, fillvalue=['-', '-', '-', '-']), start=1):
        data.append([num, value_b, value_c])
    try:
        print(AsciiTable(data).table)
    except NameError:
        column_widths = [max(len(str(item)) for item in column) + 5 for column in zip(*data)]
        
        for row in data:
            formatted_row = "|".join(f"{item:^{width}}" for item, width in zip(row, column_widths))
            print(formatted_row)

# %% [markdown]
# # Chef Class
#
# The `Chef` class represents a chef in a cooking environment. It is designed for use in a reinforcement learning scenario where the chef needs to perform various actions such as moving, taking a beater, and cooking eggs in an oven.
#
# ## Attributes
#
# - `state` (int): Current state or position of the chef in the environment.
# - `has_beater` (bool): A flag indicating whether the chef currently has a beater.
# - `q_beater` (numpy.ndarray): Q-values for actions related to taking the beater.
# - `q_cook` (numpy.ndarray): Q-values for cooking actions.
# - `actions` (list): List of possible actions for the chef ('L', 'R', 'U', 'D', 'T', 'TR', 'TL').
#
# ## Methods
#
# - `take_beater(reward)`: Attempts to take the beater, updates state and reward accordingly.
# - `cook_eggs(reward)`: Cooks eggs, updates reward, and sets cooking_done flag to True.
# - `step(state, action, illegal_moves, gates, beaters, oven)`: Takes a step in the environment based on the given action.

# %%
class Chef:

    def __init__(self, state):
        """
        Initializes a new Chef instance.

        Parameters:
        - state (int): The initial state or position of the chef in the environment.
        """
        
        self.state = state
        self.has_beater = False
        self.q_beater = np.zeros((32, 7))
        self.q_cook = np.zeros((32, 7))
        
        # LEFT, RIGHT, UP, DOWN, TAKE, TELEPORT RIGHT, TELEPORT LEFT
        self.actions = ['L', 'R', 'U', 'D', 'T', 'TR', 'TL']

    def take_beater(self, reward):
        """
        Attempts to take the beater.

        Parameters:
        - reward (float): The current reward value.

        Returns:
        - float: The updated reward value after attempting to take the beater.
        """
        
        if not self.has_beater:
            self.has_beater = True
            reward += Environment.rewards['take_beater']
        return reward

    def cook_eggs(self, reward):
        """
        Cooks eggs.

        Parameters:
        - reward (float): The current reward value.

        Returns:
        - tuple: A tuple containing the updated reward value and cooking_done flag.
        """
        
        reward += Environment.rewards['cook_eggs']
        cooking_done = True
        return reward, cooking_done
    
    def step(self, state, action, illegal_moves, gates, beaters, oven):
        """
        Takes a step in the environment based on the given action.

        Parameters:
        - state (int): The current state or position in the environment.
        - action (str): The action to be taken.
        - illegal_moves (set): Set of illegal state transitions.
        - gates (tuple): Tuple containing the positions of the teleportation gates.
        - beaters (set): Set containing positions of beaters.
        - oven (int): The position of the oven.

        Returns:
        - tuple: A tuple containing the updated state, reward, and cooking_done flag.
        """
        
        cooking_done = False
        reward = Environment.rewards['not_final']

        moves = {
            'L': action == 'L' and (state, state - 1) not in illegal_moves,
            'R': action == 'R' and (state, state + 1) not in illegal_moves,
            'U': action == 'U' and (state, state - 4) not in illegal_moves,
            'D': action == 'D' and (state, state + 4) not in illegal_moves,
            'T': action == 'T' and state in beaters,
            'TR': action == 'TR' and state == gates[0],
            'TL': action == 'TL' and state == gates[1]
        }

        if moves['L']:
            state -= 1
        elif moves['R']:
            state += 1 
        elif moves['U']:
            state -= 4
        elif moves['D']:
            state += 4
            
        elif moves['T']:
            reward = self.take_beater(reward)
            
        elif moves['TR']: # teleport 1 changing state
            state = 24
        elif moves['TL']: # teleport 2 changing state
            state = 12
            
        elif state == oven and self.has_beater:
            reward, cooking_done = self.cook_eggs(reward)
        elif (self.has_beater and action == 'T' or 
              state == oven and not self.has_beater or
              action in ['TR', 'TL'] and state not in gates):
            
            reward -= Environment.rewards['discouraged_action_penalty']

        return state, reward, cooking_done

# %% [markdown]
# # Environment Class
#
# The `Environment` class models the cooking environment where a `Chef` agent interacts. It defines the rewards for different scenarios, the layout of the environment, and the main simulation loop.
#
# ## Attributes
#
# - `rewards` (dict): Dictionary containing reward values for different scenarios.
# - `oven` (int): Position of the oven in the environment.
# - `gates` (list): Positions of teleportation gates.
# - `beaters` (list): Positions of beaters.
# - `illegal_moves` (list): List of illegal state transitions in the environment.
# - `learning_rate` (float): Learning rate for updating Q-values in the simulation.
# - `gamma` (float): Discount factor for future rewards in the Q-learning algorithm.
# - `epsilon` (float): Exploration-exploitation trade-off parameter.
#
# ## Methods
#
# - `__init__(self, learning_rate, gamma, epsilon)`: Initializes the environment with given learning parameters.
# - `generate_illegal_moves(self)`: Generates a list of illegal state transitions based on the environment layout.
# - `run(self, chef: Chef)`: Runs the simulation loop where the chef agent takes actions in the environment, and Q-values are updated accordingly.

# %%
class Environment:
    """
    The `Environment` class models the cooking environment where a `Chef` agent interacts. It defines the rewards for
    different scenarios, the layout of the environment, and the main simulation loop.

    """
    
    rewards = {"not_final": -0.5,
               "wall": -150, 
               "discouraged_action_penalty": 7.0, 
               "take_beater": 10, 
               "cook_eggs": 50}
    oven = 19
    
    def __init__(self, learning_rate, gamma, epsilon):
        """
        Initializes a new Environment instance.

        Parameters:
        - learning_rate (float): Learning rate for updating Q-values in the simulation.
        - gamma (float): Discount factor for future rewards in the Q-learning algorithm.
        - epsilon (float): Exploration-exploitation trade-off parameter.
        """
    
        self.gates = [12, 24]
        self.beaters = [5, 23]
        self.illegal_moves = self.generate_illegal_moves()
        
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon

    def generate_illegal_moves(self):
        """
        Generates a list of illegal state transitions based on the environment layout.

        Returns:
        - list: List of illegal state transitions.
        """
        
        return [
            (1, 5), (5, 6), (6, 10), (7, 11), (9, 13), (10, 14), (11, 15),                  # -------
            (5, 1), (6, 5), (10, 6), (11, 7), (13, 9), (14, 10), (15, 11),                  # | internal
            (19, 23), (20, 24), (22, 23), (26, 27), (27, 31),                               # | walls
            (23, 19), (24, 20), (23, 22), (27, 26), (31, 27),                               # --------
            (1, 0), (5, 4), (9, 8), (13, 12), (17, 16), (21, 20), (25, 24), (29, 28),       # | left   
            (4, 5), (8, 9), (12, 13), (16, 17), (20, 21), (24, 25), (28, 29), (32, 33),     # | right  - external 
            (1, -3), (2, -2), (3, -1), (4, 0), (17, 13), (18, 14), (19, 15), (20, 16),      # | up     - walls
            (13, 17), (14, 18), (15, 19), (16, 20), (29, 33), (30, 34), (31, 35), (32, 36)  # | down
        ]

    def run(self, chef: Chef):
        """
        Runs the simulation loop where the chef takes actions in the environment, and Q-values are updated accordingly.

        Parameters:
        - chef (Chef): The chef agent interacting with the environment.

        Returns:
        - float: Total reward accumulated during the simulation.
        """
        
        state = random.randint(1, 32)
        has_cooked = False
        total_reward = 0
        chef.has_beater = False
    
        while not has_cooked:
            if random.uniform(0, 1) < self.epsilon:
                action = np.random.choice(chef.actions)
            else:
                if not chef.has_beater:
                    action = chef.actions[np.argmax(chef.q_beater[state - 1])]
                else:
                    action = chef.actions[np.argmax(chef.q_cook[state - 1])]
    
            next_state, reward, cooking_done = chef.step(state, action, self.illegal_moves, self.gates, self.beaters, self.oven)
    
            if (state, next_state) in self.illegal_moves:
                reward -= Environment.rewards['wall']
    
            if not chef.has_beater:
                chef.q_beater[state - 1][chef.actions.index(action)] += self.learning_rate * (reward + self.gamma * np.max(chef.q_beater[next_state - 1]) - chef.q_beater[state - 1][chef.actions.index(action)])
            else:
                chef.q_cook[state - 1][chef.actions.index(action)] += self.learning_rate * (reward + self.gamma * np.max(chef.q_cook[next_state - 1]) - chef.q_cook[state - 1][chef.actions.index(action)])
    
            state = next_state
            total_reward += reward
    
            if cooking_done:
                has_cooked = True
    
        return total_reward

# %% [markdown]
# # Main

# %%
epsilon = 0.01
gamma = 0.8 
learning_rate = 0.2
    
environment = Environment(learning_rate=learning_rate, gamma=gamma, epsilon=epsilon)
chef = Chef(8)
max_episodes = 100000
    
for episode in range(max_episodes):
    environment.epsilon = 1 / (episode + 1)
    reward = environment.run(chef)
        
    print(f"Episode {episode + 1}, Reward: {reward}")
    
beater_optimal_policy = get_optimal_policy(chef.q_beater, chef.actions)
cook_optimal_policy = get_optimal_policy(chef.q_cook, chef.actions)
# Out:
# Episode 1, Reward: -7101.0
# Episode 2, Reward: -2405.0
# Episode 3, Reward: -417.5
# Episode 4, Reward: -270.0
# Episode 5, Reward: -81.0
# Episode 6, Reward: -46.5
# Episode 7, Reward: -183.0
# Episode 8, Reward: -48.0
# Episode 9, Reward: -89.5
# Episode 10, Reward: 6.0
# Episode 11, Reward: -108.0
# Episode 12, Reward: -32.5
# Episode 13, Reward: 0.5
# Episode 14, Reward: -27.0
# Episode 15, Reward: -123.5
# Episode 16, Reward: -50.0
# Episode 17, Reward: -28.0
# Episode 18, Reward: -76.5
# Episode 19, Reward: 18.5
# Episode 20, Reward: 20.5
# Episode 21, Reward: 4.0
# Episode 22, Reward: 27.5
# Episode 23, Reward: 40.0
# Episode 24, Reward: 30.5
# Episode 25, Reward: 11.0
# Episode 26, Reward: -5.0
# Episode 27, Reward: 2.0
# Episode 28, Reward: 28.5
# Episode 29, Reward: 25.0
# Episode 30, Reward: -19.5
# Episode 31, Reward: 30.5
# Episode 32, Reward: 8.5
# Episode 33, Reward: 36.0
# Episode 34, Reward: 20.5
# Episode 35, Reward: 44.0
# Episode 36, Reward: 8.0
# Episode 37, Reward: 43.0
# Episode 38, Reward: -0.5
# Episode 39, Reward: 20.0
# Episode 40, Reward: 25.0
# Episode 41, Reward: 28.5
# Episode 42, Reward: 25.5
# Episode 43, Reward: 24.5
# Episode 44, Reward: 41.0
# Episode 45, Reward: 29.5
# Episode 46, Reward: 25.0
# Episode 47, Reward: 44.0
# Episode 48, Reward: 51.0
# Episode 49, Reward: 35.5
# Episode 50, Reward: 49.0
# Episode 51, Reward: 26.0
# Episode 52, Reward: 25.5
# Episode 53, Reward: 51.0
# Episode 54, Reward: 40.5
# Episode 55, Reward: 41.5
# Episode 56, Reward: 41.5
# Episode 57, Reward: 50.5
# Episode 58, Reward: 34.5
# Episode 59, Reward: 53.0
# Episode 60, Reward: 51.5
# Episode 61, Reward: 52.0
# Episode 62, Reward: 38.5
# Episode 63, Reward: 47.0
# Episode 64, Reward: 29.5
# Episode 65, Reward: 51.0
# Episode 66, Reward: 8.5
# Episode 67, Reward: 30.5
# Episode 68, Reward: 52.5
# Episode 69, Reward: 48.0
# Episode 70, Reward: 51.0
# Episode 71, Reward: 52.5
# Episode 72, Reward: 43.5
# Episode 73, Reward: 44.0
# Episode 74, Reward: 51.5
# Episode 75, Reward: 46.0
# Episode 76, Reward: 26.5
# Episode 77, Reward: 37.5
# Episode 78, Reward: 50.0
# Episode 79, Reward: 28.0
# Episode 80, Reward: 51.0
# Episode 81, Reward: 52.5
# Episode 82, Reward: 47.0
# Episode 83, Reward: 36.5
# Episode 84, Reward: 49.0
# Episode 85, Reward: 49.5
# Episode 86, Reward: 38.0
# Episode 87, Reward: 37.5
# Episode 88, Reward: 28.5
# Episode 89, Reward: 53.5
# Episode 90, Reward: 45.0
# Episode 91, Reward: 30.5
# Episode 92, Reward: 30.5
# Episode 93, Reward: 53.5
# Episode 94, Reward: 26.5
# Episode 95, Reward: 51.0
# Episode 96, Reward: 49.5
# Episode 97, Reward: 39.5
# Episode 98, Reward: 51.5
# Episode 99, Reward: 54.0
# Episode 100, Reward: 33.0
# Episode 101, Reward: 53.5
# Episode 102, Reward: 52.0
# Episode 103, Reward: 52.0
# Episode 104, Reward: 44.5
# Episode 105, Reward: 45.0
# Episode 106, Reward: 53.5
# Episode 107, Reward: 54.0
# Episode 108, Reward: 38.5
# Episode 109, Reward: 53.0
# Episode 110, Reward: 51.5
# Episode 111, Reward: 53.0
# Episode 112, Reward: 50.5
# Episode 113, Reward: 45.0
# Episode 114, Reward: 53.0
# Episode 115, Reward: 31.0
# Episode 116, Reward: 51.5
# Episode 117, Reward: 44.0
# Episode 118, Reward: 48.5
# Episode 119, Reward: 53.0
# Episode 120, Reward: 50.5
# Episode 121, Reward: 48.5
# Episode 122, Reward: 48.5
# Episode 123, Reward: 42.5
# Episode 124, Reward: 51.5
# Episode 125, Reward: 42.0
# Episode 126, Reward: 53.0
# Episode 127, Reward: 31.5
# Episode 128, Reward: 53.5
# Episode 129, Reward: 32.0
# Episode 130, Reward: 50.0
# Episode 131, Reward: 51.0
# Episode 132, Reward: 46.0
# Episode 133, Reward: 53.5
# Episode 134, Reward: 51.5
# Episode 135, Reward: 53.0
# Episode 136, Reward: 35.0
# Episode 137, Reward: 45.5
# Episode 138, Reward: 54.5
# Episode 139, Reward: 51.5
# Episode 140, Reward: 41.5
# Episode 141, Reward: 52.5
# Episode 142, Reward: 50.5
# Episode 143, Reward: 52.0
# Episode 144, Reward: 43.5
# Episode 145, Reward: 50.5
# Episode 146, Reward: 39.0
# Episode 147, Reward: 45.5
# Episode 148, Reward: 53.5
# Episode 149, Reward: 39.0
# Episode 150, Reward: 51.5
# Episode 151, Reward: 50.5
# Episode 152, Reward: 31.0
# Episode 153, Reward: 52.5
# Episode 154, Reward: 52.5
# Episode 155, Reward: 53.5
# Episode 156, Reward: 51.5
# Episode 157, Reward: 31.5
# Episode 158, Reward: 47.5
# Episode 159, Reward: 37.0
# Episode 160, Reward: 52.5
# Episode 161, Reward: 48.5
# Episode 162, Reward: 38.5
# Episode 163, Reward: 52.0
# Episode 164, Reward: 45.0
# Episode 165, Reward: 50.5
# Episode 166, Reward: 52.0
# Episode 167, Reward: 54.0
# Episode 168, Reward: 47.5
# Episode 169, Reward: 44.0
# Episode 170, Reward: 33.5
# Episode 171, Reward: 50.0
# Episode 172, Reward: 52.0
# Episode 173, Reward: 51.0
# Episode 174, Reward: 47.0
# Episode 175, Reward: 42.5
# Episode 176, Reward: 42.0
# Episode 177, Reward: 54.0
# Episode 178, Reward: 54.0
# Episode 179, Reward: 36.0
# Episode 180, Reward: 53.0
# Episode 181, Reward: 42.5
# Episode 182, Reward: 38.0
# Episode 183, Reward: 39.0
# Episode 184, Reward: 50.5
# Episode 185, Reward: 52.0
# Episode 186, Reward: 50.5
# Episode 187, Reward: 41.0
# Episode 188, Reward: 49.0
# Episode 189, Reward: 45.5
# Episode 190, Reward: 52.0
# Episode 191, Reward: 52.5
# Episode 192, Reward: 42.5
# Episode 193, Reward: 53.5
# Episode 194, Reward: 46.5
# Episode 195, Reward: 52.0
# Episode 196, Reward: 52.0
# Episode 197, Reward: 46.5
# Episode 198, Reward: 49.0
# Episode 199, Reward: 51.5
# Episode 200, Reward: 43.0
# Episode 201, Reward: 52.0
# Episode 202, Reward: 44.5
# Episode 203, Reward: 53.0
# Episode 204, Reward: 45.5
# Episode 205, Reward: 45.5
# Episode 206, Reward: 51.0
# Episode 207, Reward: 53.0
# Episode 208, Reward: 51.0
# Episode 209, Reward: 35.5
# Episode 210, Reward: 51.0
# Episode 211, Reward: 50.5
# Episode 212, Reward: 52.5
# Episode 213, Reward: 52.0
# Episode 214, Reward: 38.0
# Episode 215, Reward: 46.5
# Episode 216, Reward: 53.0
# Episode 217, Reward: 38.0
# Episode 218, Reward: 53.0
# Episode 219, Reward: 51.5
# Episode 220, Reward: 54.0
# Episode 221, Reward: 51.0
# Episode 222, Reward: 53.0
# Episode 223, Reward: 47.5
# Episode 224, Reward: 54.0
# Episode 225, Reward: 51.0
# Episode 226, Reward: 54.5
# Episode 227, Reward: 43.0
# Episode 228, Reward: 51.5
# Episode 229, Reward: 44.0
# Episode 230, Reward: 53.0
# Episode 231, Reward: 51.0
# Episode 232, Reward: 50.0
# Episode 233, Reward: 54.5
# Episode 234, Reward: 53.5
# Episode 235, Reward: 48.0
# Episode 236, Reward: 52.0
# Episode 237, Reward: 53.5
# Episode 238, Reward: 51.5
# Episode 239, Reward: 47.0
# Episode 240, Reward: 51.5
# Episode 241, Reward: 50.5
# Episode 242, Reward: 46.0
# Episode 243, Reward: 51.0
# Episode 244, Reward: 53.0
# Episode 245, Reward: 48.5
# Episode 246, Reward: 52.0
# Episode 247, Reward: 47.0
# Episode 248, Reward: 48.0
# Episode 249, Reward: 51.5
# Episode 250, Reward: 52.5
# Episode 251, Reward: 50.5
# Episode 252, Reward: 49.5
# Episode 253, Reward: 48.0
# Episode 254, Reward: 53.0
# Episode 255, Reward: 48.5
# Episode 256, Reward: 47.0
# Episode 257, Reward: 51.0
# Episode 258, Reward: 50.5
# Episode 259, Reward: 51.5
# Episode 260, Reward: 43.5
# Episode 261, Reward: 52.5
# Episode 262, Reward: 49.5
# Episode 263, Reward: 52.5
# Episode 264, Reward: 53.0
# Episode 265, Reward: 52.5
# Episode 266, Reward: 48.0
# Episode 267, Reward: 48.5
# Episode 268, Reward: 51.5
# Episode 269, Reward: 53.0
# Episode 270, Reward: 51.0
# Episode 271, Reward: 49.0
# Episode 272, Reward: 53.5
# Episode 273, Reward: 52.5
# Episode 274, Reward: 48.5
# Episode 275, Reward: 49.5
# Episode 276, Reward: 52.0
# Episode 277, Reward: 48.5
# Episode 278, Reward: 51.0
# Episode 279, Reward: 51.5
# Episode 280, Reward: 51.0
# Episode 281, Reward: 50.0
# Episode 282, Reward: 46.0
# Episode 283, Reward: 51.0
# Episode 284, Reward: 48.5
# Episode 285, Reward: 49.5
# Episode 286, Reward: 49.0
# Episode 287, Reward: 54.0
# Episode 288, Reward: 50.0
# Episode 289, Reward: 53.5
# Episode 290, Reward: 52.0
# Episode 291, Reward: 49.0
# Episode 292, Reward: 53.0
# Episode 293, Reward: 53.0
# Episode 294, Reward: 49.5
# Episode 295, Reward: 52.0
# Episode 296, Reward: 50.5
# Episode 297, Reward: 51.5
# Episode 298, Reward: 54.0
# Episode 299, Reward: 52.5
# Episode 300, Reward: 49.5
# Episode 301, Reward: 54.0
# Episode 302, Reward: 52.5
# Episode 303, Reward: 53.0
# Episode 304, Reward: 54.0
# Episode 305, Reward: 53.0
# Episode 306, Reward: 51.0
# Episode 307, Reward: 52.5
# Episode 308, Reward: 52.0
# Episode 309, Reward: 54.5
# Episode 310, Reward: 50.0
# Episode 311, Reward: 51.5
# Episode 312, Reward: 49.0
# Episode 313, Reward: 52.5
# Episode 314, Reward: 49.5
# Episode 315, Reward: 51.0
# Episode 316, Reward: 53.5
# Episode 317, Reward: 49.5
# Episode 318, Reward: 50.0
# Episode 319, Reward: 50.5
# Episode 320, Reward: 53.5
# Episode 321, Reward: 50.5
# Episode 322, Reward: 53.0
# Episode 323, Reward: 52.5
# Episode 324, Reward: 50.0
# Episode 325, Reward: 53.0
# Episode 326, Reward: 52.0
# Episode 327, Reward: 51.5
# Episode 328, Reward: 54.0
# Episode 329, Reward: 54.0
# Episode 330, Reward: 50.5
# Episode 331, Reward: 50.0
# Episode 332, Reward: 49.5
# Episode 333, Reward: 44.0
# Episode 334, Reward: 52.5
# Episode 335, Reward: 53.5
# Episode 336, Reward: 48.5
# Episode 337, Reward: 51.5
# Episode 338, Reward: 53.0
# Episode 339, Reward: 50.5
# Episode 340, Reward: 49.5
# Episode 341, Reward: 50.5
# Episode 342, Reward: 51.5
# Episode 343, Reward: 50.0
# Episode 344, Reward: 51.5
# Episode 345, Reward: 48.5
# Episode 346, Reward: 53.5
# Episode 347, Reward: 48.5
# Episode 348, Reward: 52.5
# Episode 349, Reward: 53.5
# Episode 350, Reward: 52.5
# Episode 351, Reward: 54.0
# Episode 352, Reward: 52.5
# Episode 353, Reward: 51.0
# Episode 354, Reward: 52.5
# Episode 355, Reward: 53.5
# Episode 356, Reward: 50.0
# Episode 357, Reward: 51.0
# Episode 358, Reward: 50.0
# Episode 359, Reward: 50.0
# Episode 360, Reward: 52.0
# Episode 361, Reward: 52.5
# Episode 362, Reward: 53.5
# Episode 363, Reward: 50.5
# Episode 364, Reward: 53.0
# Episode 365, Reward: 44.0
# Episode 366, Reward: 49.5
# Episode 367, Reward: 53.5
# Episode 368, Reward: 51.0
# Episode 369, Reward: 51.0
# Episode 370, Reward: 53.0
# Episode 371, Reward: 47.5
# Episode 372, Reward: 51.5
# Episode 373, Reward: 51.5
# Episode 374, Reward: 50.5
# Episode 375, Reward: 50.5
# Episode 376, Reward: 51.5
# Episode 377, Reward: 54.0
# Episode 378, Reward: 52.5
# Episode 379, Reward: 50.5
# Episode 380, Reward: 50.0
# Episode 381, Reward: 53.5
# Episode 382, Reward: 52.5
# Episode 383, Reward: 50.0
# Episode 384, Reward: 51.0
# Episode 385, Reward: 52.5
# Episode 386, Reward: 52.0
# Episode 387, Reward: 48.5
# Episode 388, Reward: 49.0
# Episode 389, Reward: 50.5
# Episode 390, Reward: 51.0
# Episode 391, Reward: 53.0
# Episode 392, Reward: 52.5
# Episode 393, Reward: 50.0
# Episode 394, Reward: 50.5
# Episode 395, Reward: 52.0
# Episode 396, Reward: 50.0
# Episode 397, Reward: 51.0
# Episode 398, Reward: 48.5
# Episode 399, Reward: 46.0
# Episode 400, Reward: 51.5
# Episode 401, Reward: 50.0
# Episode 402, Reward: 52.5
# Episode 403, Reward: 49.5
# Episode 404, Reward: 53.0
# Episode 405, Reward: 52.5
# Episode 406, Reward: 52.5
# Episode 407, Reward: 50.0
# Episode 408, Reward: 49.5
# Episode 409, Reward: 53.5
# Episode 410, Reward: 52.5
# Episode 411, Reward: 42.5
# Episode 412, Reward: 50.0
# Episode 413, Reward: 54.5
# Episode 414, Reward: 52.0
# Episode 415, Reward: 52.5
# Episode 416, Reward: 52.0
# Episode 417, Reward: 51.5
# Episode 418, Reward: 50.0
# Episode 419, Reward: 53.0
# Episode 420, Reward: 51.5
# Episode 421, Reward: 51.5
# Episode 422, Reward: 48.5
# Episode 423, Reward: 53.0
# Episode 424, Reward: 51.5
# Episode 425, Reward: 52.0
# Episode 426, Reward: 50.5
# Episode 427, Reward: 49.0
# Episode 428, Reward: 51.5
# Episode 429, Reward: 51.0
# Episode 430, Reward: 49.5
# Episode 431, Reward: 53.0
# Episode 432, Reward: 52.0
# Episode 433, Reward: 51.0
# Episode 434, Reward: 50.0
# Episode 435, Reward: 52.5
# Episode 436, Reward: 54.0
# Episode 437, Reward: 50.5
# Episode 438, Reward: 51.5
# Episode 439, Reward: 49.5
# Episode 440, Reward: 50.0
# Episode 441, Reward: 53.5
# Episode 442, Reward: 53.0
# Episode 443, Reward: 52.5
# Episode 444, Reward: 51.5
# Episode 445, Reward: 51.0
# Episode 446, Reward: 52.0
# Episode 447, Reward: 52.5
# Episode 448, Reward: 53.0
# Episode 449, Reward: 50.0
# Episode 450, Reward: 50.0
# Episode 451, Reward: 50.0
# Episode 452, Reward: 53.0
# Episode 453, Reward: 50.0
# Episode 454, Reward: 53.5
# Episode 455, Reward: 52.5
# Episode 456, Reward: 50.0
# Episode 457, Reward: 54.0
# Episode 458, Reward: 54.0
# Episode 459, Reward: 51.5
# Episode 460, Reward: 51.0
# Episode 461, Reward: 54.0
# Episode 462, Reward: 50.0
# Episode 463, Reward: 49.5
# Episode 464, Reward: 51.5
# Episode 465, Reward: 50.5
# Episode 466, Reward: 48.0
# Episode 467, Reward: 49.5
# Episode 468, Reward: 53.0
# Episode 469, Reward: 51.0
# Episode 470, Reward: 49.0
# Episode 471, Reward: 50.0
# Episode 472, Reward: 52.0
# Episode 473, Reward: 51.5
# Episode 474, Reward: 50.0
# Episode 475, Reward: 52.5
# Episode 476, Reward: 52.0
# Episode 477, Reward: 53.0
# Episode 478, Reward: 51.5
# Episode 479, Reward: 51.0
# Episode 480, Reward: 49.5
# Episode 481, Reward: 53.0
# Episode 482, Reward: 49.5
# Episode 483, Reward: 54.0
# Episode 484, Reward: 47.0
# Episode 485, Reward: 53.0
# Episode 486, Reward: 51.5
# Episode 487, Reward: 51.0
# Episode 488, Reward: 51.5
# Episode 489, Reward: 51.5
# Episode 490, Reward: 47.5
# Episode 491, Reward: 52.5
# Episode 492, Reward: 49.5
# Episode 493, Reward: 51.0
# Episode 494, Reward: 50.0
# Episode 495, Reward: 51.0
# Episode 496, Reward: 49.0
# Episode 497, Reward: 49.5
# Episode 498, Reward: 52.0
# Episode 499, Reward: 50.0
# Episode 500, Reward: 53.0
# Episode 501, Reward: 50.0
# Episode 502, Reward: 48.5
# Episode 503, Reward: 49.5
# Episode 504, Reward: 51.5
# Episode 505, Reward: 50.5
# Episode 506, Reward: 50.5
# Episode 507, Reward: 54.5
# Episode 508, Reward: 50.0
# Episode 509, Reward: 51.5
# Episode 510, Reward: 52.0
# Episode 511, Reward: 49.5
# Episode 512, Reward: 50.5
# Episode 513, Reward: 53.0
# Episode 514, Reward: 50.5
# Episode 515, Reward: 53.0
# Episode 516, Reward: 53.0
# Episode 517, Reward: 51.5
# Episode 518, Reward: 50.5
# Episode 519, Reward: 52.0
# Episode 520, Reward: 51.5
# Episode 521, Reward: 50.5
# Episode 522, Reward: 48.0
# Episode 523, Reward: 50.5
# Episode 524, Reward: 48.5
# Episode 525, Reward: 51.0
# Episode 526, Reward: 53.0
# Episode 527, Reward: 54.0
# Episode 528, Reward: 51.5
# Episode 529, Reward: 53.5
# Episode 530, Reward: 51.5
# Episode 531, Reward: 49.5
# Episode 532, Reward: 52.5
# Episode 533, Reward: 51.0
# Episode 534, Reward: 53.5
# Episode 535, Reward: 53.5
# Episode 536, Reward: 51.5
# Episode 537, Reward: 50.5
# Episode 538, Reward: 52.0
# Episode 539, Reward: 49.5
# Episode 540, Reward: 52.0
# Episode 541, Reward: 51.0
# Episode 542, Reward: 50.0
# Episode 543, Reward: 51.5
# Episode 544, Reward: 49.0
# Episode 545, Reward: 52.5
# Episode 546, Reward: 50.5
# Episode 547, Reward: 50.5
# Episode 548, Reward: 53.5
# Episode 549, Reward: 53.5
# Episode 550, Reward: 52.5
# Episode 551, Reward: 49.5
# Episode 552, Reward: 50.0
# Episode 553, Reward: 51.5
# Episode 554, Reward: 51.5
# Episode 555, Reward: 50.0
# Episode 556, Reward: 48.0
# Episode 557, Reward: 48.5
# Episode 558, Reward: 52.5
# Episode 559, Reward: 52.5
# Episode 560, Reward: 51.0
# Episode 561, Reward: 54.0
# Episode 562, Reward: 52.5
# Episode 563, Reward: 53.0
# Episode 564, Reward: 50.0
# Episode 565, Reward: 52.5
# Episode 566, Reward: 51.5
# Episode 567, Reward: 51.5
# Episode 568, Reward: 54.0
# Episode 569, Reward: 44.5
# Episode 570, Reward: 50.0
# Episode 571, Reward: 54.0
# Episode 572, Reward: 50.0
# Episode 573, Reward: 50.5
# Episode 574, Reward: 52.5
# Episode 575, Reward: 50.5
# Episode 576, Reward: 54.5
# Episode 577, Reward: 51.5
# Episode 578, Reward: 52.5
# Episode 579, Reward: 52.0
# Episode 580, Reward: 53.0
# Episode 581, Reward: 51.5
# Episode 582, Reward: 52.5
# Episode 583, Reward: 53.0
# Episode 584, Reward: 50.0
# Episode 585, Reward: 49.5
# Episode 586, Reward: 49.0
# Episode 587, Reward: 50.5
# Episode 588, Reward: 52.0
# Episode 589, Reward: 51.0
# Episode 590, Reward: 48.0
# Episode 591, Reward: 53.0
# Episode 592, Reward: 49.0
# Episode 593, Reward: 51.5
# Episode 594, Reward: 52.5
# Episode 595, Reward: 51.0
# Episode 596, Reward: 53.5
# Episode 597, Reward: 51.5
# Episode 598, Reward: 53.0
# Episode 599, Reward: 49.0
# Episode 600, Reward: 53.0
# Episode 601, Reward: 53.5
# Episode 602, Reward: 52.0
# Episode 603, Reward: 51.5
# Episode 604, Reward: 52.0
# Episode 605, Reward: 49.5
# Episode 606, Reward: 52.5
# Episode 607, Reward: 50.0
# Episode 608, Reward: 54.0
# Episode 609, Reward: 49.5
# Episode 610, Reward: 50.0
# Episode 611, Reward: 52.0
# Episode 612, Reward: 51.0
# Episode 613, Reward: 51.5
# Episode 614, Reward: 51.0
# Episode 615, Reward: 52.5
# Episode 616, Reward: 53.0
# Episode 617, Reward: 51.0
# Episode 618, Reward: 51.0
# Episode 619, Reward: 51.5
# Episode 620, Reward: 54.0
# Episode 621, Reward: 51.0
# Episode 622, Reward: 53.5
# Episode 623, Reward: 50.5
# Episode 624, Reward: 52.5
# Episode 625, Reward: 50.5
# Episode 626, Reward: 51.0
# Episode 627, Reward: 52.5
# Episode 628, Reward: 51.5
# Episode 629, Reward: 53.0
# Episode 630, Reward: 49.5
# Episode 631, Reward: 51.0
# Episode 632, Reward: 50.5
# Episode 633, Reward: 48.5
# Episode 634, Reward: 54.0
# Episode 635, Reward: 50.0
# Episode 636, Reward: 50.0
# Episode 637, Reward: 54.0
# Episode 638, Reward: 50.5
# Episode 639, Reward: 54.5
# Episode 640, Reward: 50.0
# Episode 641, Reward: 53.0
# Episode 642, Reward: 51.5
# Episode 643, Reward: 47.5
# Episode 644, Reward: 54.0
# Episode 645, Reward: 52.0
# Episode 646, Reward: 51.5
# Episode 647, Reward: 52.0
# Episode 648, Reward: 51.5
# Episode 649, Reward: 49.5
# Episode 650, Reward: 50.0
# Episode 651, Reward: 50.5
# Episode 652, Reward: 52.0
# Episode 653, Reward: 53.0
# Episode 654, Reward: 52.0
# Episode 655, Reward: 50.5
# Episode 656, Reward: 54.0
# Episode 657, Reward: 51.0
# Episode 658, Reward: 52.0
# Episode 659, Reward: 50.5
# Episode 660, Reward: 50.5
# Episode 661, Reward: 49.5
# Episode 662, Reward: 51.5
# Episode 663, Reward: 51.0
# Episode 664, Reward: 53.5
# Episode 665, Reward: 53.0
# Episode 666, Reward: 51.5
# Episode 667, Reward: 51.5
# Episode 668, Reward: 44.0
# Episode 669, Reward: 52.0
# Episode 670, Reward: 50.0
# Episode 671, Reward: 53.0
# Episode 672, Reward: 53.5
# Episode 673, Reward: 53.5
# Episode 674, Reward: 52.5
# Episode 675, Reward: 53.0
# Episode 676, Reward: 48.5
# Episode 677, Reward: 50.5
# Episode 678, Reward: 50.5
# Episode 679, Reward: 52.0
# Episode 680, Reward: 51.5
# Episode 681, Reward: 51.0
# Episode 682, Reward: 50.5
# Episode 683, Reward: 52.5
# Episode 684, Reward: 52.0
# Episode 685, Reward: 52.5
# Episode 686, Reward: 49.0
# Episode 687, Reward: 51.0
# Episode 688, Reward: 51.0
# Episode 689, Reward: 50.5
# Episode 690, Reward: 51.0
# Episode 691, Reward: 50.0
# Episode 692, Reward: 53.5
# Episode 693, Reward: 49.5
# Episode 694, Reward: 50.0
# Episode 695, Reward: 51.5
# Episode 696, Reward: 53.5
# Episode 697, Reward: 52.5
# Episode 698, Reward: 50.0
# Episode 699, Reward: 53.5
# Episode 700, Reward: 51.5
# Episode 701, Reward: 49.5
# Episode 702, Reward: 52.0
# Episode 703, Reward: 52.5
# Episode 704, Reward: 51.5
# Episode 705, Reward: 50.0
# Episode 706, Reward: 52.5
# Episode 707, Reward: 51.0
# Episode 708, Reward: 50.0
# Episode 709, Reward: 51.5
# Episode 710, Reward: 51.5
# Episode 711, Reward: 52.5
# Episode 712, Reward: 49.5
# Episode 713, Reward: 53.5
# Episode 714, Reward: 51.0
# Episode 715, Reward: 53.5
# Episode 716, Reward: 50.0
# Episode 717, Reward: 50.5
# Episode 718, Reward: 54.0
# Episode 719, Reward: 53.0
# Episode 720, Reward: 49.0
# Episode 721, Reward: 53.5
# Episode 722, Reward: 52.5
# Episode 723, Reward: 51.0
# Episode 724, Reward: 52.5
# Episode 725, Reward: 53.5
# Episode 726, Reward: 52.0
# Episode 727, Reward: 51.5
# Episode 728, Reward: 52.5
# Episode 729, Reward: 51.0
# Episode 730, Reward: 52.0
# Episode 731, Reward: 53.5
# Episode 732, Reward: 53.0
# Episode 733, Reward: 53.5
# Episode 734, Reward: 50.5
# Episode 735, Reward: 51.5
# Episode 736, Reward: 52.5
# Episode 737, Reward: 50.5
# Episode 738, Reward: 51.0
# Episode 739, Reward: 52.0
# Episode 740, Reward: 52.5
# Episode 741, Reward: 50.5
# Episode 742, Reward: 52.5
# Episode 743, Reward: 51.5
# Episode 744, Reward: 51.0
# Episode 745, Reward: 51.5
# Episode 746, Reward: 49.5
# Episode 747, Reward: 54.5
# Episode 748, Reward: 51.0
# Episode 749, Reward: 52.5
# Episode 750, Reward: 54.5
# Episode 751, Reward: 50.0
# Episode 752, Reward: 53.5
# Episode 753, Reward: 52.0
# Episode 754, Reward: 53.0
# Episode 755, Reward: 53.5
# Episode 756, Reward: 49.0
# Episode 757, Reward: 52.5
# Episode 758, Reward: 52.0
# Episode 759, Reward: 50.5
# Episode 760, Reward: 50.0
# Episode 761, Reward: 52.0
# Episode 762, Reward: 54.0
# Episode 763, Reward: 49.5
# Episode 764, Reward: 51.5
# Episode 765, Reward: 53.0
# Episode 766, Reward: 52.0
# Episode 767, Reward: 51.5
# Episode 768, Reward: 52.0
# Episode 769, Reward: 51.5
# Episode 770, Reward: 52.5
# Episode 771, Reward: 52.0
# Episode 772, Reward: 51.5
# Episode 773, Reward: 51.5
# Episode 774, Reward: 52.5
# Episode 775, Reward: 50.0
# Episode 776, Reward: 50.5
# Episode 777, Reward: 53.0
# Episode 778, Reward: 52.5
# Episode 779, Reward: 51.5
# Episode 780, Reward: 51.5
# Episode 781, Reward: 49.5
# Episode 782, Reward: 49.0
# Episode 783, Reward: 51.5
# Episode 784, Reward: 50.0
# Episode 785, Reward: 52.0
# Episode 786, Reward: 53.0
# Episode 787, Reward: 52.0
# Episode 788, Reward: 51.5
# Episode 789, Reward: 50.5
# Episode 790, Reward: 52.0
# Episode 791, Reward: 50.5
# Episode 792, Reward: 50.5
# Episode 793, Reward: 50.5
# Episode 794, Reward: 50.0
# Episode 795, Reward: 53.0
# Episode 796, Reward: 52.0
# Episode 797, Reward: 52.0
# Episode 798, Reward: 51.5
# Episode 799, Reward: 49.0
# Episode 800, Reward: 53.0
# Episode 801, Reward: 51.5
# Episode 802, Reward: 52.5
# Episode 803, Reward: 51.5
# Episode 804, Reward: 54.5
# Episode 805, Reward: 52.5
# Episode 806, Reward: 50.0
# Episode 807, Reward: 51.5
# Episode 808, Reward: 52.0
# Episode 809, Reward: 52.0
# Episode 810, Reward: 50.0
# Episode 811, Reward: 49.5
# Episode 812, Reward: 50.5
# Episode 813, Reward: 52.5
# Episode 814, Reward: 51.5
# Episode 815, Reward: 50.5
# Episode 816, Reward: 50.0
# Episode 817, Reward: 52.5
# Episode 818, Reward: 50.0
# Episode 819, Reward: 48.5
# Episode 820, Reward: 51.5
# Episode 821, Reward: 50.5
# Episode 822, Reward: 51.0
# Episode 823, Reward: 53.5
# Episode 824, Reward: 53.5
# Episode 825, Reward: 53.0
# Episode 826, Reward: 51.0
# Episode 827, Reward: 53.0
# Episode 828, Reward: 53.0
# Episode 829, Reward: 52.0
# Episode 830, Reward: 52.0
# Episode 831, Reward: 52.5
# Episode 832, Reward: 50.5
# Episode 833, Reward: 52.5
# Episode 834, Reward: 51.0
# Episode 835, Reward: 49.0
# Episode 836, Reward: 51.5
# Episode 837, Reward: 54.0
# Episode 838, Reward: 52.0
# Episode 839, Reward: 50.0
# Episode 840, Reward: 54.0
# Episode 841, Reward: 51.0
# Episode 842, Reward: 50.0
# Episode 843, Reward: 49.5
# Episode 844, Reward: 53.5
# Episode 845, Reward: 51.5
# Episode 846, Reward: 49.5
# Episode 847, Reward: 52.5
# Episode 848, Reward: 50.0
# Episode 849, Reward: 51.0
# Episode 850, Reward: 54.5
# Episode 851, Reward: 52.0
# Episode 852, Reward: 51.0
# Episode 853, Reward: 52.5
# Episode 854, Reward: 50.5
# Episode 855, Reward: 51.0
# Episode 856, Reward: 51.5
# Episode 857, Reward: 50.5
# Episode 858, Reward: 51.5
# Episode 859, Reward: 52.0
# Episode 860, Reward: 49.5
# Episode 861, Reward: 51.5
# Episode 862, Reward: 51.5
# Episode 863, Reward: 50.0
# Episode 864, Reward: 50.5
# Episode 865, Reward: 49.5
# Episode 866, Reward: 51.5
# Episode 867, Reward: 50.5
# Episode 868, Reward: 46.5
# Episode 869, Reward: 53.0
# Episode 870, Reward: 50.0
# Episode 871, Reward: 51.5
# Episode 872, Reward: 52.5
# Episode 873, Reward: 50.5
# Episode 874, Reward: 50.5
# Episode 875, Reward: 52.5
# Episode 876, Reward: 50.5
# Episode 877, Reward: 52.0
# Episode 878, Reward: 50.5
# Episode 879, Reward: 53.5
# Episode 880, Reward: 52.5
# Episode 881, Reward: 54.5
# Episode 882, Reward: 50.5
# Episode 883, Reward: 51.0
# Episode 884, Reward: 51.5
# Episode 885, Reward: 53.0
# Episode 886, Reward: 50.5
# Episode 887, Reward: 53.0
# Episode 888, Reward: 50.0
# Episode 889, Reward: 51.5
# Episode 890, Reward: 50.5
# Episode 891, Reward: 50.0
# Episode 892, Reward: 52.0
# Episode 893, Reward: 53.0
# Episode 894, Reward: 52.5
# Episode 895, Reward: 53.0
# Episode 896, Reward: 53.0
# Episode 897, Reward: 51.5
# Episode 898, Reward: 51.0
# Episode 899, Reward: 52.0
# Episode 900, Reward: 51.5
# Episode 901, Reward: 50.0
# Episode 902, Reward: 52.0
# Episode 903, Reward: 50.5
# Episode 904, Reward: 50.5
# Episode 905, Reward: 51.0
# Episode 906, Reward: 50.0
# Episode 907, Reward: 50.5
# Episode 908, Reward: 53.0
# Episode 909, Reward: 49.5
# Episode 910, Reward: 53.0
# Episode 911, Reward: 50.0
# Episode 912, Reward: 53.0
# Episode 913, Reward: 54.5
# Episode 914, Reward: 50.5
# Episode 915, Reward: 50.0
# Episode 916, Reward: 49.5
# Episode 917, Reward: 50.5
# Episode 918, Reward: 52.0
# Episode 919, Reward: 50.5
# Episode 920, Reward: 50.5
# Episode 921, Reward: 53.0
# Episode 922, Reward: 51.5
# Episode 923, Reward: 52.0
# Episode 924, Reward: 50.5
# Episode 925, Reward: 49.5
# Episode 926, Reward: 50.0
# Episode 927, Reward: 51.0
# Episode 928, Reward: 52.0
# Episode 929, Reward: 51.0
# Episode 930, Reward: 49.5
# Episode 931, Reward: 50.5
# Episode 932, Reward: 51.0
# Episode 933, Reward: 54.0
# Episode 934, Reward: 50.5
# Episode 935, Reward: 50.5
# Episode 936, Reward: 50.5
# Episode 937, Reward: 52.5
# Episode 938, Reward: 51.0
# Episode 939, Reward: 52.5
# Episode 940, Reward: 51.5
# Episode 941, Reward: 53.5
# Episode 942, Reward: 54.0
# Episode 943, Reward: 52.5
# Episode 944, Reward: 51.0
# Episode 945, Reward: 52.5
# Episode 946, Reward: 50.0
# Episode 947, Reward: 48.5
# Episode 948, Reward: 50.5
# Episode 949, Reward: 50.5
# Episode 950, Reward: 52.0
# Episode 951, Reward: 51.0
# Episode 952, Reward: 54.0
# Episode 953, Reward: 50.0
# Episode 954, Reward: 51.0
# Episode 955, Reward: 54.0
# Episode 956, Reward: 50.5
# Episode 957, Reward: 50.5
# Episode 958, Reward: 52.5
# Episode 959, Reward: 54.0
# Episode 960, Reward: 52.0
# Episode 961, Reward: 53.5
# Episode 962, Reward: 52.5
# Episode 963, Reward: 54.0
# Episode 964, Reward: 52.0
# Episode 965, Reward: 51.5
# Episode 966, Reward: 53.0
# Episode 967, Reward: 53.0
# Episode 968, Reward: 51.5
# Episode 969, Reward: 50.5
# Episode 970, Reward: 51.0
# Episode 971, Reward: 50.0
# Episode 972, Reward: 53.0
# Episode 973, Reward: 52.0
# Episode 974, Reward: 52.0
# Episode 975, Reward: 52.5
# Episode 976, Reward: 52.0
# Episode 977, Reward: 52.0
# Episode 978, Reward: 53.5
# Episode 979, Reward: 49.5
# Episode 980, Reward: 53.0
# Episode 981, Reward: 54.5
# Episode 982, Reward: 49.5
# Episode 983, Reward: 52.5
# Episode 984, Reward: 51.0
# Episode 985, Reward: 50.5
# Episode 986, Reward: 54.0
# Episode 987, Reward: 51.5
# Episode 988, Reward: 50.5
# Episode 989, Reward: 51.5
# Episode 990, Reward: 50.0
# Episode 991, Reward: 51.5
# Episode 992, Reward: 52.5
# Episode 993, Reward: 53.5
# Episode 994, Reward: 50.0
# Episode 995, Reward: 52.5
# Episode 996, Reward: 53.5
# Episode 997, Reward: 50.5
# Episode 998, Reward: 50.5
# Episode 999, Reward: 49.5
# Episode 1000, Reward: 53.0
# Episode 1001, Reward: 50.0
# Episode 1002, Reward: 50.5
# Episode 1003, Reward: 53.0
# Episode 1004, Reward: 53.5
# Episode 1005, Reward: 51.0
# Episode 1006, Reward: 52.5
# Episode 1007, Reward: 53.0
# Episode 1008, Reward: 49.5
# Episode 1009, Reward: 52.0
# Episode 1010, Reward: 50.0
# Episode 1011, Reward: 51.5
# Episode 1012, Reward: 52.5
# Episode 1013, Reward: 50.5
# Episode 1014, Reward: 51.0
# Episode 1015, Reward: 52.5
# Episode 1016, Reward: 53.5
# Episode 1017, Reward: 50.0
# Episode 1018, Reward: 52.5
# Episode 1019, Reward: 52.0
# Episode 1020, Reward: 51.5
# Episode 1021, Reward: 51.0
# Episode 1022, Reward: 52.5
# Episode 1023, Reward: 51.0
# Episode 1024, Reward: 52.5
# Episode 1025, Reward: 49.5
# Episode 1026, Reward: 54.0
# Episode 1027, Reward: 52.5
# Episode 1028, Reward: 52.0
# Episode 1029, Reward: 53.5
# Episode 1030, Reward: 50.5
# Episode 1031, Reward: 50.5
# Episode 1032, Reward: 49.0
# Episode 1033, Reward: 53.5
# Episode 1034, Reward: 51.0
# Episode 1035, Reward: 52.0
# Episode 1036, Reward: 51.0
# Episode 1037, Reward: 52.5
# Episode 1038, Reward: 50.0
# Episode 1039, Reward: 51.0
# Episode 1040, Reward: 51.5
# Episode 1041, Reward: 53.5
# Episode 1042, Reward: 51.0
# Episode 1043, Reward: 49.5
# Episode 1044, Reward: 53.5
# Episode 1045, Reward: 52.5
# Episode 1046, Reward: 52.5
# Episode 1047, Reward: 50.5
# Episode 1048, Reward: 50.5
# Episode 1049, Reward: 51.0
# Episode 1050, Reward: 52.0
# Episode 1051, Reward: 52.0
# Episode 1052, Reward: 51.5
# Episode 1053, Reward: 51.5
# Episode 1054, Reward: 52.0
# Episode 1055, Reward: 51.0
# Episode 1056, Reward: 52.5
# Episode 1057, Reward: 51.0
# Episode 1058, Reward: 51.5
# Episode 1059, Reward: 49.0
# Episode 1060, Reward: 52.0
# Episode 1061, Reward: 53.5
# Episode 1062, Reward: 51.0
# Episode 1063, Reward: 50.5
# Episode 1064, Reward: 52.5
# Episode 1065, Reward: 53.0
# Episode 1066, Reward: 50.5
# Episode 1067, Reward: 51.0
# Episode 1068, Reward: 51.0
# Episode 1069, Reward: 53.5
# Episode 1070, Reward: 51.0
# Episode 1071, Reward: 49.5
# Episode 1072, Reward: 52.5
# Episode 1073, Reward: 51.5
# Episode 1074, Reward: 50.0
# Episode 1075, Reward: 54.5
# Episode 1076, Reward: 52.5
# Episode 1077, Reward: 52.5
# Episode 1078, Reward: 50.5
# Episode 1079, Reward: 50.0
# Episode 1080, Reward: 50.0
# Episode 1081, Reward: 52.5
# Episode 1082, Reward: 51.0
# Episode 1083, Reward: 51.5
# Episode 1084, Reward: 51.5
# Episode 1085, Reward: 54.0
# Episode 1086, Reward: 51.0
# Episode 1087, Reward: 52.5
# Episode 1088, Reward: 51.5
# Episode 1089, Reward: 53.5
# Episode 1090, Reward: 49.5
# Episode 1091, Reward: 53.5
# Episode 1092, Reward: 50.5
# Episode 1093, Reward: 50.5
# Episode 1094, Reward: 53.5
# Episode 1095, Reward: 49.0
# Episode 1096, Reward: 50.5
# Episode 1097, Reward: 51.5
# Episode 1098, Reward: 52.5
# Episode 1099, Reward: 51.0
# Episode 1100, Reward: 51.5
# Episode 1101, Reward: 51.5
# Episode 1102, Reward: 50.0
# Episode 1103, Reward: 52.0
# Episode 1104, Reward: 50.5
# Episode 1105, Reward: 50.5
# Episode 1106, Reward: 51.0
# Episode 1107, Reward: 50.0
# Episode 1108, Reward: 52.5
# Episode 1109, Reward: 51.0
# Episode 1110, Reward: 51.0
# Episode 1111, Reward: 49.0
# Episode 1112, Reward: 50.0
# Episode 1113, Reward: 50.5
# Episode 1114, Reward: 54.0
# Episode 1115, Reward: 50.0
# Episode 1116, Reward: 52.0
# Episode 1117, Reward: 53.5
# Episode 1118, Reward: 50.0
# Episode 1119, Reward: 49.5
# Episode 1120, Reward: 49.5
# Episode 1121, Reward: 54.5
# Episode 1122, Reward: 52.5
# Episode 1123, Reward: 51.0
# Episode 1124, Reward: 50.0
# Episode 1125, Reward: 49.5
# Episode 1126, Reward: 53.0
# Episode 1127, Reward: 51.0
# Episode 1128, Reward: 53.5
# Episode 1129, Reward: 49.5
# Episode 1130, Reward: 51.0
# Episode 1131, Reward: 50.0
# Episode 1132, Reward: 52.0
# Episode 1133, Reward: 53.0
# Episode 1134, Reward: 54.0
# Episode 1135, Reward: 52.5
# Episode 1136, Reward: 50.5
# Episode 1137, Reward: 53.0
# Episode 1138, Reward: 52.0
# Episode 1139, Reward: 50.5
# Episode 1140, Reward: 50.5
# Episode 1141, Reward: 52.5
# Episode 1142, Reward: 53.5
# Episode 1143, Reward: 49.5
# Episode 1144, Reward: 51.0
# Episode 1145, Reward: 53.5
# Episode 1146, Reward: 52.0
# Episode 1147, Reward: 52.0
# Episode 1148, Reward: 51.0
# Episode 1149, Reward: 53.5
# Episode 1150, Reward: 51.5
# Episode 1151, Reward: 52.5
# Episode 1152, Reward: 49.5
# Episode 1153, Reward: 52.0
# Episode 1154, Reward: 49.5
# Episode 1155, Reward: 51.5
# Episode 1156, Reward: 50.0
# Episode 1157, Reward: 53.0
# Episode 1158, Reward: 51.0
# Episode 1159, Reward: 49.0
# Episode 1160, Reward: 53.0
# Episode 1161, Reward: 49.5
# Episode 1162, Reward: 50.0
# Episode 1163, Reward: 51.5
# Episode 1164, Reward: 51.0
# Episode 1165, Reward: 54.0
# Episode 1166, Reward: 53.5
# Episode 1167, Reward: 50.5
# Episode 1168, Reward: 51.0
# Episode 1169, Reward: 54.0
# Episode 1170, Reward: 50.0
# Episode 1171, Reward: 51.0
# Episode 1172, Reward: 53.5
# Episode 1173, Reward: 51.5
# Episode 1174, Reward: 52.0
# Episode 1175, Reward: 53.0
# Episode 1176, Reward: 51.0
# Episode 1177, Reward: 51.5
# Episode 1178, Reward: 51.5
# Episode 1179, Reward: 50.5
# Episode 1180, Reward: 54.5
# Episode 1181, Reward: 52.5
# Episode 1182, Reward: 51.5
# Episode 1183, Reward: 51.0
# Episode 1184, Reward: 53.5
# Episode 1185, Reward: 53.5
# Episode 1186, Reward: 52.5
# Episode 1187, Reward: 51.0
# Episode 1188, Reward: 51.5
# Episode 1189, Reward: 52.5
# Episode 1190, Reward: 52.5
# Episode 1191, Reward: 52.5
# Episode 1192, Reward: 51.5
# Episode 1193, Reward: 50.5
# Episode 1194, Reward: 53.5
# Episode 1195, Reward: 54.0
# Episode 1196, Reward: 50.5
# Episode 1197, Reward: 50.5
# Episode 1198, Reward: 49.5
# Episode 1199, Reward: 52.5
# Episode 1200, Reward: 52.5
# Episode 1201, Reward: 51.0
# Episode 1202, Reward: 49.5
# Episode 1203, Reward: 50.0
# Episode 1204, Reward: 52.0
# Episode 1205, Reward: 52.0
# Episode 1206, Reward: 51.0
# Episode 1207, Reward: 51.0
# Episode 1208, Reward: 51.5
# Episode 1209, Reward: 49.5
# Episode 1210, Reward: 51.5
# Episode 1211, Reward: 51.0
# Episode 1212, Reward: 50.0
# Episode 1213, Reward: 49.5
# Episode 1214, Reward: 51.0
# Episode 1215, Reward: 54.0
# Episode 1216, Reward: 51.5
# Episode 1217, Reward: 49.5
# Episode 1218, Reward: 50.5
# Episode 1219, Reward: 52.5
# Episode 1220, Reward: 53.5
# Episode 1221, Reward: 50.0
# Episode 1222, Reward: 50.5
# Episode 1223, Reward: 52.5
# Episode 1224, Reward: 53.5
# Episode 1225, Reward: 49.5
# Episode 1226, Reward: 52.0
# Episode 1227, Reward: 53.0
# Episode 1228, Reward: 50.5
# Episode 1229, Reward: 50.5
# Episode 1230, Reward: 51.0
# Episode 1231, Reward: 50.5
# Episode 1232, Reward: 53.5
# Episode 1233, Reward: 52.5
# Episode 1234, Reward: 52.5
# Episode 1235, Reward: 49.5
# Episode 1236, Reward: 53.0
# Episode 1237, Reward: 52.5
# Episode 1238, Reward: 52.0
# Episode 1239, Reward: 50.5
# Episode 1240, Reward: 50.0
# Episode 1241, Reward: 53.0
# Episode 1242, Reward: 51.0
# Episode 1243, Reward: 51.5
# Episode 1244, Reward: 53.5
# Episode 1245, Reward: 51.0
# Episode 1246, Reward: 52.5
# Episode 1247, Reward: 52.0
# Episode 1248, Reward: 52.0
# Episode 1249, Reward: 53.0
# Episode 1250, Reward: 51.5
# Episode 1251, Reward: 51.5
# Episode 1252, Reward: 51.5
# Episode 1253, Reward: 52.5
# Episode 1254, Reward: 52.0
# Episode 1255, Reward: 50.5
# Episode 1256, Reward: 51.0
# Episode 1257, Reward: 51.0
# Episode 1258, Reward: 51.0
# Episode 1259, Reward: 52.0
# Episode 1260, Reward: 52.5
# Episode 1261, Reward: 51.5
# Episode 1262, Reward: 51.0
# Episode 1263, Reward: 53.5
# Episode 1264, Reward: 51.0
# Episode 1265, Reward: 49.5
# Episode 1266, Reward: 52.5
# Episode 1267, Reward: 51.5
# Episode 1268, Reward: 51.0
# Episode 1269, Reward: 50.0
# Episode 1270, Reward: 52.0
# Episode 1271, Reward: 49.5
# Episode 1272, Reward: 50.0
# Episode 1273, Reward: 49.0
# Episode 1274, Reward: 51.0
# Episode 1275, Reward: 53.5
# Episode 1276, Reward: 50.0
# Episode 1277, Reward: 52.0
# Episode 1278, Reward: 50.5
# Episode 1279, Reward: 52.0
# Episode 1280, Reward: 53.0
# Episode 1281, Reward: 53.0
# Episode 1282, Reward: 51.5
# Episode 1283, Reward: 50.5
# Episode 1284, Reward: 52.0
# Episode 1285, Reward: 50.5
# Episode 1286, Reward: 52.5
# Episode 1287, Reward: 51.5
# Episode 1288, Reward: 51.0
# Episode 1289, Reward: 49.5
# Episode 1290, Reward: 51.5
# Episode 1291, Reward: 50.5
# Episode 1292, Reward: 51.0
# Episode 1293, Reward: 52.0
# Episode 1294, Reward: 49.0
# Episode 1295, Reward: 50.0
# Episode 1296, Reward: 51.5
# Episode 1297, Reward: 51.0
# Episode 1298, Reward: 53.5
# Episode 1299, Reward: 51.5
# Episode 1300, Reward: 50.5
# Episode 1301, Reward: 51.0
# Episode 1302, Reward: 52.5
# Episode 1303, Reward: 51.0
# Episode 1304, Reward: 53.0
# Episode 1305, Reward: 51.0
# Episode 1306, Reward: 51.0
# Episode 1307, Reward: 53.0
# Episode 1308, Reward: 50.5
# Episode 1309, Reward: 49.5
# Episode 1310, Reward: 53.0
# Episode 1311, Reward: 51.5
# Episode 1312, Reward: 51.5
# Episode 1313, Reward: 43.5
# Episode 1314, Reward: 53.0
# Episode 1315, Reward: 51.5
# Episode 1316, Reward: 51.0
# Episode 1317, Reward: 51.0
# Episode 1318, Reward: 51.5
# Episode 1319, Reward: 52.5
# Episode 1320, Reward: 52.5
# Episode 1321, Reward: 50.5
# Episode 1322, Reward: 52.5
# Episode 1323, Reward: 52.0
# Episode 1324, Reward: 51.0
# Episode 1325, Reward: 53.5
# Episode 1326, Reward: 51.0
# Episode 1327, Reward: 51.0
# Episode 1328, Reward: 51.0
# Episode 1329, Reward: 50.5
# Episode 1330, Reward: 51.0
# Episode 1331, Reward: 53.5
# Episode 1332, Reward: 49.5
# Episode 1333, Reward: 51.0
# Episode 1334, Reward: 52.5
# Episode 1335, Reward: 53.5
# Episode 1336, Reward: 49.5
# Episode 1337, Reward: 54.0
# Episode 1338, Reward: 51.0
# Episode 1339, Reward: 51.0
# Episode 1340, Reward: 51.0
# Episode 1341, Reward: 50.0
# Episode 1342, Reward: 52.5
# Episode 1343, Reward: 52.0
# Episode 1344, Reward: 51.0
# Episode 1345, Reward: 53.0
# Episode 1346, Reward: 52.0
# Episode 1347, Reward: 49.5
# Episode 1348, Reward: 52.0
# Episode 1349, Reward: 52.0
# Episode 1350, Reward: 50.5
# Episode 1351, Reward: 51.5
# Episode 1352, Reward: 53.0
# Episode 1353, Reward: 52.5
# Episode 1354, Reward: 50.0
# Episode 1355, Reward: 53.0
# Episode 1356, Reward: 53.5
# Episode 1357, Reward: 52.0
# Episode 1358, Reward: 51.5
# Episode 1359, Reward: 42.5
# Episode 1360, Reward: 52.5
# Episode 1361, Reward: 51.5
# Episode 1362, Reward: 50.5
# Episode 1363, Reward: 50.0
# Episode 1364, Reward: 51.5
# Episode 1365, Reward: 51.0
# Episode 1366, Reward: 53.5
# Episode 1367, Reward: 53.5
# Episode 1368, Reward: 51.5
# Episode 1369, Reward: 50.0
# Episode 1370, Reward: 50.5
# Episode 1371, Reward: 50.0
# Episode 1372, Reward: 52.0
# Episode 1373, Reward: 51.0
# Episode 1374, Reward: 51.5
# Episode 1375, Reward: 52.0
# Episode 1376, Reward: 51.5
# Episode 1377, Reward: 51.5
# Episode 1378, Reward: 49.5
# Episode 1379, Reward: 52.5
# Episode 1380, Reward: 52.5
# Episode 1381, Reward: 51.5
# Episode 1382, Reward: 52.0
# Episode 1383, Reward: 51.5
# Episode 1384, Reward: 51.0
# Episode 1385, Reward: 52.5
# Episode 1386, Reward: 52.5
# Episode 1387, Reward: 51.0
# Episode 1388, Reward: 50.5
# Episode 1389, Reward: 49.0
# Episode 1390, Reward: 52.5
# Episode 1391, Reward: 50.5
# Episode 1392, Reward: 50.0
# Episode 1393, Reward: 49.0
# Episode 1394, Reward: 52.5
# Episode 1395, Reward: 53.5
# Episode 1396, Reward: 54.5
# Episode 1397, Reward: 52.5
# Episode 1398, Reward: 50.5
# Episode 1399, Reward: 54.0
# Episode 1400, Reward: 50.5
# Episode 1401, Reward: 52.5
# Episode 1402, Reward: 54.5
# Episode 1403, Reward: 50.5
# Episode 1404, Reward: 50.0
# Episode 1405, Reward: 50.5
# Episode 1406, Reward: 51.5
# Episode 1407, Reward: 50.5
# Episode 1408, Reward: 52.0
# Episode 1409, Reward: 53.0
# Episode 1410, Reward: 53.0
# Episode 1411, Reward: 50.5
# Episode 1412, Reward: 52.0
# Episode 1413, Reward: 43.0
# Episode 1414, Reward: 51.5
# Episode 1415, Reward: 52.5
# Episode 1416, Reward: 51.0
# Episode 1417, Reward: 53.5
# Episode 1418, Reward: 52.5
# Episode 1419, Reward: 51.0
# Episode 1420, Reward: 50.5
# Episode 1421, Reward: 52.5
# Episode 1422, Reward: 50.5
# Episode 1423, Reward: 50.5
# Episode 1424, Reward: 51.0
# Episode 1425, Reward: 52.5
# Episode 1426, Reward: 51.0
# Episode 1427, Reward: 50.0
# Episode 1428, Reward: 53.5
# Episode 1429, Reward: 51.0
# Episode 1430, Reward: 50.0
# Episode 1431, Reward: 52.0
# Episode 1432, Reward: 51.0
# Episode 1433, Reward: 50.0
# Episode 1434, Reward: 51.5
# Episode 1435, Reward: 52.5
# Episode 1436, Reward: 50.0
# Episode 1437, Reward: 51.5
# Episode 1438, Reward: 51.5
# Episode 1439, Reward: 52.0
# Episode 1440, Reward: 50.0
# Episode 1441, Reward: 51.0
# Episode 1442, Reward: 50.0
# Episode 1443, Reward: 51.5
# Episode 1444, Reward: 53.0
# Episode 1445, Reward: 51.5
# Episode 1446, Reward: 52.0
# Episode 1447, Reward: 50.5
# Episode 1448, Reward: 52.5
# Episode 1449, Reward: 54.5
# Episode 1450, Reward: 49.5
# Episode 1451, Reward: 52.5
# Episode 1452, Reward: 53.0
# Episode 1453, Reward: 50.5
# Episode 1454, Reward: 54.5
# Episode 1455, Reward: 51.5
# Episode 1456, Reward: 53.5
# Episode 1457, Reward: 53.0
# Episode 1458, Reward: 53.0
# Episode 1459, Reward: 54.0
# Episode 1460, Reward: 51.5
# Episode 1461, Reward: 52.0
# Episode 1462, Reward: 53.0
# Episode 1463, Reward: 51.0
# Episode 1464, Reward: 53.5
# Episode 1465, Reward: 52.5
# Episode 1466, Reward: 52.0
# Episode 1467, Reward: 54.0
# Episode 1468, Reward: 51.5
# Episode 1469, Reward: 50.0
# Episode 1470, Reward: 52.5
# Episode 1471, Reward: 52.0
# Episode 1472, Reward: 54.0
# Episode 1473, Reward: 51.0
# Episode 1474, Reward: 52.0
# Episode 1475, Reward: 51.5
# Episode 1476, Reward: 53.0
# Episode 1477, Reward: 50.5
# Episode 1478, Reward: 50.5
# Episode 1479, Reward: 53.5
# Episode 1480, Reward: 52.0
# Episode 1481, Reward: 50.5
# Episode 1482, Reward: 52.5
# Episode 1483, Reward: 50.5
# Episode 1484, Reward: 54.5
# Episode 1485, Reward: 52.5
# Episode 1486, Reward: 52.0
# Episode 1487, Reward: 52.5
# Episode 1488, Reward: 51.0
# Episode 1489, Reward: 50.0
# Episode 1490, Reward: 52.0
# Episode 1491, Reward: 52.0
# Episode 1492, Reward: 52.5
# Episode 1493, Reward: 52.0
# Episode 1494, Reward: 50.0
# Episode 1495, Reward: 52.0
# Episode 1496, Reward: 54.0
# Episode 1497, Reward: 50.5
# Episode 1498, Reward: 53.0
# Episode 1499, Reward: 50.5
# Episode 1500, Reward: 51.5
# Episode 1501, Reward: 53.0
# Episode 1502, Reward: 52.5
# Episode 1503, Reward: 52.0
# Episode 1504, Reward: 50.0
# Episode 1505, Reward: 51.0
# Episode 1506, Reward: 51.0
# Episode 1507, Reward: 51.0
# Episode 1508, Reward: 50.0
# Episode 1509, Reward: 51.5
# Episode 1510, Reward: 51.0
# Episode 1511, Reward: 50.0
# Episode 1512, Reward: 50.0
# Episode 1513, Reward: 52.0
# Episode 1514, Reward: 53.5
# Episode 1515, Reward: 52.5
# Episode 1516, Reward: 51.5
# Episode 1517, Reward: 51.5
# Episode 1518, Reward: 53.0
# Episode 1519, Reward: 51.5
# Episode 1520, Reward: 51.0
# Episode 1521, Reward: 49.0
# Episode 1522, Reward: 52.5
# Episode 1523, Reward: 50.0
# Episode 1524, Reward: 52.0
# Episode 1525, Reward: 53.5
# Episode 1526, Reward: 51.0
# Episode 1527, Reward: 50.0
# Episode 1528, Reward: 52.0
# Episode 1529, Reward: 51.5
# Episode 1530, Reward: 49.5
# Episode 1531, Reward: 51.5
# Episode 1532, Reward: 52.5
# Episode 1533, Reward: 52.0
# Episode 1534, Reward: 51.5
# Episode 1535, Reward: 52.5
# Episode 1536, Reward: 53.0
# Episode 1537, Reward: 53.5
# Episode 1538, Reward: 53.0
# Episode 1539, Reward: 51.0
# Episode 1540, Reward: 50.5
# Episode 1541, Reward: 52.0
# Episode 1542, Reward: 51.0
# Episode 1543, Reward: 53.0
# Episode 1544, Reward: 49.5
# Episode 1545, Reward: 51.5
# Episode 1546, Reward: 50.0
# Episode 1547, Reward: 52.0
# Episode 1548, Reward: 50.0
# Episode 1549, Reward: 49.0
# Episode 1550, Reward: 49.5
# Episode 1551, Reward: 51.0
# Episode 1552, Reward: 51.5
# Episode 1553, Reward: 52.0
# Episode 1554, Reward: 52.5
# Episode 1555, Reward: 49.0
# Episode 1556, Reward: 52.5
# Episode 1557, Reward: 50.5
# Episode 1558, Reward: 51.5
# Episode 1559, Reward: 51.0
# Episode 1560, Reward: 51.0
# Episode 1561, Reward: 49.0
# Episode 1562, Reward: 50.5
# Episode 1563, Reward: 52.0
# Episode 1564, Reward: 51.5
# Episode 1565, Reward: 53.0
# Episode 1566, Reward: 51.5
# Episode 1567, Reward: 50.0
# Episode 1568, Reward: 49.5
# Episode 1569, Reward: 50.0
# Episode 1570, Reward: 50.5
# Episode 1571, Reward: 50.5
# Episode 1572, Reward: 52.5
# Episode 1573, Reward: 54.0
# Episode 1574, Reward: 54.0
# Episode 1575, Reward: 51.5
# Episode 1576, Reward: 51.0
# Episode 1577, Reward: 51.0
# Episode 1578, Reward: 52.5
# Episode 1579, Reward: 53.0
# Episode 1580, Reward: 51.0
# Episode 1581, Reward: 51.0
# Episode 1582, Reward: 50.5
# Episode 1583, Reward: 50.5
# Episode 1584, Reward: 49.0
# Episode 1585, Reward: 52.0
# Episode 1586, Reward: 51.0
# Episode 1587, Reward: 53.0
# Episode 1588, Reward: 52.5
# Episode 1589, Reward: 53.5
# Episode 1590, Reward: 49.5
# Episode 1591, Reward: 51.0
# Episode 1592, Reward: 51.0
# Episode 1593, Reward: 50.0
# Episode 1594, Reward: 49.0
# Episode 1595, Reward: 51.0
# Episode 1596, Reward: 52.5
# Episode 1597, Reward: 54.0
# Episode 1598, Reward: 50.5
# Episode 1599, Reward: 53.5
# Episode 1600, Reward: 54.0
# Episode 1601, Reward: 50.0
# Episode 1602, Reward: 50.0
# Episode 1603, Reward: 54.0
# Episode 1604, Reward: 50.5
# Episode 1605, Reward: 52.0
# Episode 1606, Reward: 50.5
# Episode 1607, Reward: 50.5
# Episode 1608, Reward: 53.0
# Episode 1609, Reward: 51.0
# Episode 1610, Reward: 53.5
# Episode 1611, Reward: 52.5
# Episode 1612, Reward: 51.5
# Episode 1613, Reward: 51.5
# Episode 1614, Reward: 51.5
# Episode 1615, Reward: 51.0
# Episode 1616, Reward: 51.5
# Episode 1617, Reward: 51.5
# Episode 1618, Reward: 52.5
# Episode 1619, Reward: 52.5
# Episode 1620, Reward: 53.0
# Episode 1621, Reward: 49.5
# Episode 1622, Reward: 54.0
# Episode 1623, Reward: 50.0
# Episode 1624, Reward: 51.0
# Episode 1625, Reward: 52.5
# Episode 1626, Reward: 52.5
# Episode 1627, Reward: 52.0
# Episode 1628, Reward: 54.0
# Episode 1629, Reward: 51.5
# Episode 1630, Reward: 53.5
# Episode 1631, Reward: 53.5
# Episode 1632, Reward: 53.0
# Episode 1633, Reward: 52.0
# Episode 1634, Reward: 52.0
# Episode 1635, Reward: 51.0
# Episode 1636, Reward: 53.0
# Episode 1637, Reward: 54.0
# Episode 1638, Reward: 52.0
# Episode 1639, Reward: 50.5
# Episode 1640, Reward: 51.5
# Episode 1641, Reward: 52.0
# Episode 1642, Reward: 49.0
# Episode 1643, Reward: 52.5
# Episode 1644, Reward: 45.0
# Episode 1645, Reward: 50.5
# Episode 1646, Reward: 50.0
# Episode 1647, Reward: 52.0
# Episode 1648, Reward: 52.0
# Episode 1649, Reward: 49.5
# Episode 1650, Reward: 50.0
# Episode 1651, Reward: 50.5
# Episode 1652, Reward: 50.0
# Episode 1653, Reward: 53.0
# Episode 1654, Reward: 51.0
# Episode 1655, Reward: 52.5
# Episode 1656, Reward: 51.5
# Episode 1657, Reward: 52.0
# Episode 1658, Reward: 50.5
# Episode 1659, Reward: 54.0
# Episode 1660, Reward: 49.0
# Episode 1661, Reward: 53.0
# Episode 1662, Reward: 52.0
# Episode 1663, Reward: 52.0
# Episode 1664, Reward: 50.5
# Episode 1665, Reward: 51.0
# Episode 1666, Reward: 51.5
# Episode 1667, Reward: 53.0
# Episode 1668, Reward: 50.5
# Episode 1669, Reward: 51.5
# Episode 1670, Reward: 53.0
# Episode 1671, Reward: 50.5
# Episode 1672, Reward: 50.0
# Episode 1673, Reward: 53.5
# Episode 1674, Reward: 54.0
# Episode 1675, Reward: 50.0
# Episode 1676, Reward: 50.0
# Episode 1677, Reward: 50.5
# Episode 1678, Reward: 53.0
# Episode 1679, Reward: 53.5
# Episode 1680, Reward: 52.5
# Episode 1681, Reward: 52.5
# Episode 1682, Reward: 50.5
# Episode 1683, Reward: 51.5
# Episode 1684, Reward: 53.0
# Episode 1685, Reward: 53.5
# Episode 1686, Reward: 53.0
# Episode 1687, Reward: 50.0
# Episode 1688, Reward: 51.0
# Episode 1689, Reward: 51.0
# Episode 1690, Reward: 50.5
# Episode 1691, Reward: 51.0
# Episode 1692, Reward: 50.5
# Episode 1693, Reward: 51.5
# Episode 1694, Reward: 53.0
# Episode 1695, Reward: 52.0
# Episode 1696, Reward: 50.0
# Episode 1697, Reward: 53.5
# Episode 1698, Reward: 49.5
# Episode 1699, Reward: 51.5
# Episode 1700, Reward: 51.5
# Episode 1701, Reward: 52.0
# Episode 1702, Reward: 53.0
# Episode 1703, Reward: 49.5
# Episode 1704, Reward: 51.0
# Episode 1705, Reward: 50.0
# Episode 1706, Reward: 50.0
# Episode 1707, Reward: 51.5
# Episode 1708, Reward: 52.5
# Episode 1709, Reward: 51.0
# Episode 1710, Reward: 50.0
# Episode 1711, Reward: 50.5
# Episode 1712, Reward: 52.5
# Episode 1713, Reward: 53.0
# Episode 1714, Reward: 51.0
# Episode 1715, Reward: 50.5
# Episode 1716, Reward: 50.0
# Episode 1717, Reward: 50.0
# Episode 1718, Reward: 54.0
# Episode 1719, Reward: 50.0
# Episode 1720, Reward: 50.5
# Episode 1721, Reward: 52.5
# Episode 1722, Reward: 53.0
# Episode 1723, Reward: 51.5
# Episode 1724, Reward: 52.0
# Episode 1725, Reward: 53.0
# Episode 1726, Reward: 51.5
# Episode 1727, Reward: 53.5
# Episode 1728, Reward: 53.0
# Episode 1729, Reward: 51.5
# Episode 1730, Reward: 52.0
# Episode 1731, Reward: 52.5
# Episode 1732, Reward: 50.0
# Episode 1733, Reward: 53.0
# Episode 1734, Reward: 49.5
# Episode 1735, Reward: 49.5
# Episode 1736, Reward: 51.0
# Episode 1737, Reward: 51.0
# Episode 1738, Reward: 50.0
# Episode 1739, Reward: 52.5
# Episode 1740, Reward: 53.0
# Episode 1741, Reward: 49.0
# Episode 1742, Reward: 54.0
# Episode 1743, Reward: 51.5
# Episode 1744, Reward: 49.5
# Episode 1745, Reward: 52.5
# Episode 1746, Reward: 52.0
# Episode 1747, Reward: 50.0
# Episode 1748, Reward: 51.5
# Episode 1749, Reward: 50.5
# Episode 1750, Reward: 50.5
# Episode 1751, Reward: 53.0
# Episode 1752, Reward: 51.5
# Episode 1753, Reward: 50.5
# Episode 1754, Reward: 50.0
# Episode 1755, Reward: 52.0
# Episode 1756, Reward: 53.0
# Episode 1757, Reward: 53.5
# Episode 1758, Reward: 52.0
# Episode 1759, Reward: 50.0
# Episode 1760, Reward: 50.0
# Episode 1761, Reward: 50.5
# Episode 1762, Reward: 49.5
# Episode 1763, Reward: 52.5
# Episode 1764, Reward: 49.5
# Episode 1765, Reward: 52.0
# Episode 1766, Reward: 49.5
# Episode 1767, Reward: 52.5
# Episode 1768, Reward: 52.0
# Episode 1769, Reward: 52.0
# Episode 1770, Reward: 53.0
# Episode 1771, Reward: 53.5
# Episode 1772, Reward: 52.5
# Episode 1773, Reward: 52.0
# Episode 1774, Reward: 51.0
# Episode 1775, Reward: 51.0
# Episode 1776, Reward: 45.5
# Episode 1777, Reward: 50.5
# Episode 1778, Reward: 52.5
# Episode 1779, Reward: 53.0
# Episode 1780, Reward: 51.0
# Episode 1781, Reward: 49.0
# Episode 1782, Reward: 52.0
# Episode 1783, Reward: 51.5
# Episode 1784, Reward: 52.5
# Episode 1785, Reward: 51.0
# Episode 1786, Reward: 49.5
# Episode 1787, Reward: 52.0
# Episode 1788, Reward: 52.5
# Episode 1789, Reward: 49.0
# Episode 1790, Reward: 53.5
# Episode 1791, Reward: 53.5
# Episode 1792, Reward: 52.0
# Episode 1793, Reward: 51.5
# Episode 1794, Reward: 50.0
# Episode 1795, Reward: 53.5
# Episode 1796, Reward: 52.5
# Episode 1797, Reward: 42.0
# Episode 1798, Reward: 53.0
# Episode 1799, Reward: 50.5
# Episode 1800, Reward: 53.0
# Episode 1801, Reward: 51.5
# Episode 1802, Reward: 50.5
# Episode 1803, Reward: 52.0
# Episode 1804, Reward: 50.0
# Episode 1805, Reward: 50.5
# Episode 1806, Reward: 52.0
# Episode 1807, Reward: 52.5
# Episode 1808, Reward: 52.5
# Episode 1809, Reward: 50.0
# Episode 1810, Reward: 51.5
# Episode 1811, Reward: 52.0
# Episode 1812, Reward: 50.5
# Episode 1813, Reward: 49.5
# Episode 1814, Reward: 52.5
# Episode 1815, Reward: 52.5
# Episode 1816, Reward: 50.5
# Episode 1817, Reward: 54.0
# Episode 1818, Reward: 49.5
# ...
# Episode 99430, Reward: 50.0
# Episode 99431, Reward: 50.5
# Episode 99432, Reward: 51.5
# Episode 99433, Reward: 51.5
# Episode 99434, Reward: 51.5
# Episode 99435, Reward: 50.0
# Episode 99436, Reward: 52.5
# Episode 99437, Reward: 49.0
# Episode 99438, Reward: 50.0
# Episode 99439, Reward: 51.0
# Episode 99440, Reward: 52.5
# Episode 99441, Reward: 51.0
# Episode 99442, Reward: 52.0
# Episode 99443, Reward: 51.0
# Episode 99444, Reward: 52.0
# Episode 99445, Reward: 51.0
# Episode 99446, Reward: 51.0
# Episode 99447, Reward: 52.0
# Episode 99448, Reward: 52.5
# Episode 99449, Reward: 51.5
# Episode 99450, Reward: 51.5
# Episode 99451, Reward: 52.0
# Episode 99452, Reward: 52.5
# Episode 99453, Reward: 50.0
# Episode 99454, Reward: 51.0
# Episode 99455, Reward: 52.5
# Episode 99456, Reward: 50.0
# Episode 99457, Reward: 53.0
# Episode 99458, Reward: 51.5
# Episode 99459, Reward: 52.5
# Episode 99460, Reward: 49.0
# Episode 99461, Reward: 53.0
# Episode 99462, Reward: 51.0
# Episode 99463, Reward: 49.0
# Episode 99464, Reward: 50.0
# Episode 99465, Reward: 51.0
# Episode 99466, Reward: 50.0
# Episode 99467, Reward: 51.0
# Episode 99468, Reward: 51.0
# Episode 99469, Reward: 50.5
# Episode 99470, Reward: 53.5
# Episode 99471, Reward: 51.5
# Episode 99472, Reward: 54.0
# Episode 99473, Reward: 50.0
# Episode 99474, Reward: 49.5
# Episode 99475, Reward: 51.0
# Episode 99476, Reward: 52.0
# Episode 99477, Reward: 53.0
# Episode 99478, Reward: 49.0
# Episode 99479, Reward: 50.0
# Episode 99480, Reward: 52.5
# Episode 99481, Reward: 51.5
# Episode 99482, Reward: 53.0
# Episode 99483, Reward: 51.0
# Episode 99484, Reward: 52.0
# Episode 99485, Reward: 52.0
# Episode 99486, Reward: 50.5
# Episode 99487, Reward: 53.0
# Episode 99488, Reward: 49.5
# Episode 99489, Reward: 51.5
# Episode 99490, Reward: 51.5
# Episode 99491, Reward: 52.5
# Episode 99492, Reward: 53.0
# Episode 99493, Reward: 49.5
# Episode 99494, Reward: 51.5
# Episode 99495, Reward: 53.0
# Episode 99496, Reward: 51.0
# Episode 99497, Reward: 54.0
# Episode 99498, Reward: 50.5
# Episode 99499, Reward: 52.0
# Episode 99500, Reward: 53.5
# Episode 99501, Reward: 52.5
# Episode 99502, Reward: 51.5
# Episode 99503, Reward: 52.5
# Episode 99504, Reward: 51.0
# Episode 99505, Reward: 49.5
# Episode 99506, Reward: 51.5
# Episode 99507, Reward: 51.0
# Episode 99508, Reward: 51.0
# Episode 99509, Reward: 49.0
# Episode 99510, Reward: 52.5
# Episode 99511, Reward: 50.0
# Episode 99512, Reward: 52.0
# Episode 99513, Reward: 50.5
# Episode 99514, Reward: 52.0
# Episode 99515, Reward: 51.0
# Episode 99516, Reward: 51.5
# Episode 99517, Reward: 51.0
# Episode 99518, Reward: 51.0
# Episode 99519, Reward: 53.0
# Episode 99520, Reward: 50.0
# Episode 99521, Reward: 51.0
# Episode 99522, Reward: 52.0
# Episode 99523, Reward: 51.5
# Episode 99524, Reward: 51.0
# Episode 99525, Reward: 52.0
# Episode 99526, Reward: 50.0
# Episode 99527, Reward: 50.5
# Episode 99528, Reward: 52.5
# Episode 99529, Reward: 51.0
# Episode 99530, Reward: 52.0
# Episode 99531, Reward: 52.5
# Episode 99532, Reward: 53.5
# Episode 99533, Reward: 49.5
# Episode 99534, Reward: 49.0
# Episode 99535, Reward: 50.0
# Episode 99536, Reward: 51.0
# Episode 99537, Reward: 51.5
# Episode 99538, Reward: 51.0
# Episode 99539, Reward: 51.5
# Episode 99540, Reward: 52.0
# Episode 99541, Reward: 52.5
# Episode 99542, Reward: 54.5
# Episode 99543, Reward: 53.0
# Episode 99544, Reward: 51.0
# Episode 99545, Reward: 52.0
# Episode 99546, Reward: 52.5
# Episode 99547, Reward: 49.5
# Episode 99548, Reward: 53.0
# Episode 99549, Reward: 52.0
# Episode 99550, Reward: 49.5
# Episode 99551, Reward: 50.5
# Episode 99552, Reward: 50.5
# Episode 99553, Reward: 52.0
# Episode 99554, Reward: 50.0
# Episode 99555, Reward: 51.0
# Episode 99556, Reward: 51.5
# Episode 99557, Reward: 53.0
# Episode 99558, Reward: 52.0
# Episode 99559, Reward: 50.5
# Episode 99560, Reward: 51.5
# Episode 99561, Reward: 49.5
# Episode 99562, Reward: 52.0
# Episode 99563, Reward: 49.0
# Episode 99564, Reward: 51.0
# Episode 99565, Reward: 50.0
# Episode 99566, Reward: 51.5
# Episode 99567, Reward: 53.0
# Episode 99568, Reward: 51.0
# Episode 99569, Reward: 50.0
# Episode 99570, Reward: 51.0
# Episode 99571, Reward: 52.5
# Episode 99572, Reward: 51.5
# Episode 99573, Reward: 51.5
# Episode 99574, Reward: 51.0
# Episode 99575, Reward: 51.5
# Episode 99576, Reward: 50.0
# Episode 99577, Reward: 53.5
# Episode 99578, Reward: 49.5
# Episode 99579, Reward: 49.0
# Episode 99580, Reward: 51.5
# Episode 99581, Reward: 54.0
# Episode 99582, Reward: 49.0
# Episode 99583, Reward: 51.0
# Episode 99584, Reward: 50.5
# Episode 99585, Reward: 52.5
# Episode 99586, Reward: 52.5
# Episode 99587, Reward: 53.5
# Episode 99588, Reward: 50.0
# Episode 99589, Reward: 50.5
# Episode 99590, Reward: 52.5
# Episode 99591, Reward: 50.0
# Episode 99592, Reward: 52.5
# Episode 99593, Reward: 51.0
# Episode 99594, Reward: 53.0
# Episode 99595, Reward: 52.5
# Episode 99596, Reward: 53.5
# Episode 99597, Reward: 52.0
# Episode 99598, Reward: 51.0
# Episode 99599, Reward: 51.0
# Episode 99600, Reward: 53.0
# Episode 99601, Reward: 53.0
# Episode 99602, Reward: 51.5
# Episode 99603, Reward: 53.0
# Episode 99604, Reward: 50.0
# Episode 99605, Reward: 53.5
# Episode 99606, Reward: 49.0
# Episode 99607, Reward: 51.5
# Episode 99608, Reward: 51.0
# Episode 99609, Reward: 49.5
# Episode 99610, Reward: 54.5
# Episode 99611, Reward: 51.5
# Episode 99612, Reward: 52.5
# Episode 99613, Reward: 53.0
# Episode 99614, Reward: 52.5
# Episode 99615, Reward: 51.0
# Episode 99616, Reward: 52.5
# Episode 99617, Reward: 50.0
# Episode 99618, Reward: 52.0
# Episode 99619, Reward: 50.5
# Episode 99620, Reward: 51.0
# Episode 99621, Reward: 52.5
# Episode 99622, Reward: 50.0
# Episode 99623, Reward: 54.5
# Episode 99624, Reward: 52.0
# Episode 99625, Reward: 49.5
# Episode 99626, Reward: 50.0
# Episode 99627, Reward: 52.5
# Episode 99628, Reward: 50.5
# Episode 99629, Reward: 51.0
# Episode 99630, Reward: 50.0
# Episode 99631, Reward: 51.0
# Episode 99632, Reward: 51.0
# Episode 99633, Reward: 50.5
# Episode 99634, Reward: 51.5
# Episode 99635, Reward: 50.5
# Episode 99636, Reward: 51.5
# Episode 99637, Reward: 51.0
# Episode 99638, Reward: 51.5
# Episode 99639, Reward: 51.0
# Episode 99640, Reward: 53.5
# Episode 99641, Reward: 51.0
# Episode 99642, Reward: 54.0
# Episode 99643, Reward: 50.0
# Episode 99644, Reward: 50.0
# Episode 99645, Reward: 51.5
# Episode 99646, Reward: 51.0
# Episode 99647, Reward: 50.0
# Episode 99648, Reward: 52.5
# Episode 99649, Reward: 51.5
# Episode 99650, Reward: 51.5
# Episode 99651, Reward: 51.0
# Episode 99652, Reward: 53.0
# Episode 99653, Reward: 53.0
# Episode 99654, Reward: 52.5
# Episode 99655, Reward: 52.5
# Episode 99656, Reward: 51.5
# Episode 99657, Reward: 52.5
# Episode 99658, Reward: 52.5
# Episode 99659, Reward: 51.0
# Episode 99660, Reward: 52.0
# Episode 99661, Reward: 52.5
# Episode 99662, Reward: 52.5
# Episode 99663, Reward: 52.5
# Episode 99664, Reward: 49.5
# Episode 99665, Reward: 50.5
# Episode 99666, Reward: 52.0
# Episode 99667, Reward: 51.5
# Episode 99668, Reward: 53.0
# Episode 99669, Reward: 51.5
# Episode 99670, Reward: 52.0
# Episode 99671, Reward: 51.0
# Episode 99672, Reward: 53.0
# Episode 99673, Reward: 52.5
# Episode 99674, Reward: 50.5
# Episode 99675, Reward: 51.5
# Episode 99676, Reward: 51.0
# Episode 99677, Reward: 52.5
# Episode 99678, Reward: 53.0
# Episode 99679, Reward: 50.0
# Episode 99680, Reward: 53.0
# Episode 99681, Reward: 50.0
# Episode 99682, Reward: 51.0
# Episode 99683, Reward: 52.0
# Episode 99684, Reward: 50.0
# Episode 99685, Reward: 53.5
# Episode 99686, Reward: 53.0
# Episode 99687, Reward: 51.5
# Episode 99688, Reward: 51.0
# Episode 99689, Reward: 53.5
# Episode 99690, Reward: 52.0
# Episode 99691, Reward: 53.5
# Episode 99692, Reward: 51.0
# Episode 99693, Reward: 51.5
# Episode 99694, Reward: 54.0
# Episode 99695, Reward: 50.0
# Episode 99696, Reward: 50.0
# Episode 99697, Reward: 51.0
# Episode 99698, Reward: 50.0
# Episode 99699, Reward: 51.0
# Episode 99700, Reward: 52.0
# Episode 99701, Reward: 51.0
# Episode 99702, Reward: 52.5
# Episode 99703, Reward: 51.0
# Episode 99704, Reward: 50.5
# Episode 99705, Reward: 53.5
# Episode 99706, Reward: 54.0
# Episode 99707, Reward: 51.0
# Episode 99708, Reward: 51.0
# Episode 99709, Reward: 53.0
# Episode 99710, Reward: 50.5
# Episode 99711, Reward: 52.5
# Episode 99712, Reward: 52.5
# Episode 99713, Reward: 50.0
# Episode 99714, Reward: 50.5
# Episode 99715, Reward: 50.0
# Episode 99716, Reward: 49.5
# Episode 99717, Reward: 52.5
# Episode 99718, Reward: 52.5
# Episode 99719, Reward: 53.5
# Episode 99720, Reward: 49.0
# Episode 99721, Reward: 52.0
# Episode 99722, Reward: 53.0
# Episode 99723, Reward: 52.5
# Episode 99724, Reward: 53.0
# Episode 99725, Reward: 50.5
# Episode 99726, Reward: 50.5
# Episode 99727, Reward: 50.5
# Episode 99728, Reward: 51.0
# Episode 99729, Reward: 52.5
# Episode 99730, Reward: 51.0
# Episode 99731, Reward: 53.0
# Episode 99732, Reward: 52.0
# Episode 99733, Reward: 51.5
# Episode 99734, Reward: 50.0
# Episode 99735, Reward: 51.5
# Episode 99736, Reward: 54.5
# Episode 99737, Reward: 52.5
# Episode 99738, Reward: 52.0
# Episode 99739, Reward: 49.0
# Episode 99740, Reward: 53.0
# Episode 99741, Reward: 51.0
# Episode 99742, Reward: 51.0
# Episode 99743, Reward: 52.5
# Episode 99744, Reward: 51.0
# Episode 99745, Reward: 50.5
# Episode 99746, Reward: 49.5
# Episode 99747, Reward: 52.5
# Episode 99748, Reward: 49.0
# Episode 99749, Reward: 50.0
# Episode 99750, Reward: 53.5
# Episode 99751, Reward: 49.5
# Episode 99752, Reward: 50.5
# Episode 99753, Reward: 50.0
# Episode 99754, Reward: 51.0
# Episode 99755, Reward: 53.5
# Episode 99756, Reward: 51.0
# Episode 99757, Reward: 51.0
# Episode 99758, Reward: 51.5
# Episode 99759, Reward: 52.5
# Episode 99760, Reward: 52.0
# Episode 99761, Reward: 52.0
# Episode 99762, Reward: 52.5
# Episode 99763, Reward: 51.0
# Episode 99764, Reward: 53.5
# Episode 99765, Reward: 52.0
# Episode 99766, Reward: 52.5
# Episode 99767, Reward: 52.5
# Episode 99768, Reward: 53.5
# Episode 99769, Reward: 53.0
# Episode 99770, Reward: 50.0
# Episode 99771, Reward: 53.5
# Episode 99772, Reward: 53.5
# Episode 99773, Reward: 50.0
# Episode 99774, Reward: 51.5
# Episode 99775, Reward: 52.5
# Episode 99776, Reward: 52.0
# Episode 99777, Reward: 50.0
# Episode 99778, Reward: 51.0
# Episode 99779, Reward: 50.5
# Episode 99780, Reward: 52.5
# Episode 99781, Reward: 51.0
# Episode 99782, Reward: 52.0
# Episode 99783, Reward: 51.0
# Episode 99784, Reward: 51.5
# Episode 99785, Reward: 50.0
# Episode 99786, Reward: 53.0
# Episode 99787, Reward: 51.5
# Episode 99788, Reward: 51.5
# Episode 99789, Reward: 52.0
# Episode 99790, Reward: 51.0
# Episode 99791, Reward: 53.5
# Episode 99792, Reward: 51.5
# Episode 99793, Reward: 49.5
# Episode 99794, Reward: 52.0
# Episode 99795, Reward: 49.5
# Episode 99796, Reward: 52.0
# Episode 99797, Reward: 52.5
# Episode 99798, Reward: 52.0
# Episode 99799, Reward: 51.5
# Episode 99800, Reward: 51.0
# Episode 99801, Reward: 52.0
# Episode 99802, Reward: 52.0
# Episode 99803, Reward: 50.0
# Episode 99804, Reward: 50.0
# Episode 99805, Reward: 51.5
# Episode 99806, Reward: 53.5
# Episode 99807, Reward: 51.0
# Episode 99808, Reward: 50.5
# Episode 99809, Reward: 54.0
# Episode 99810, Reward: 52.5
# Episode 99811, Reward: 50.5
# Episode 99812, Reward: 52.5
# Episode 99813, Reward: 50.5
# Episode 99814, Reward: 51.0
# Episode 99815, Reward: 50.5
# Episode 99816, Reward: 52.0
# Episode 99817, Reward: 50.0
# Episode 99818, Reward: 52.5
# Episode 99819, Reward: 51.5
# Episode 99820, Reward: 51.0
# Episode 99821, Reward: 52.5
# Episode 99822, Reward: 51.0
# Episode 99823, Reward: 53.0
# Episode 99824, Reward: 49.5
# Episode 99825, Reward: 50.5
# Episode 99826, Reward: 51.5
# Episode 99827, Reward: 52.0
# Episode 99828, Reward: 51.5
# Episode 99829, Reward: 51.0
# Episode 99830, Reward: 51.5
# Episode 99831, Reward: 51.0
# Episode 99832, Reward: 54.0
# Episode 99833, Reward: 53.0
# Episode 99834, Reward: 51.0
# Episode 99835, Reward: 54.0
# Episode 99836, Reward: 51.0
# Episode 99837, Reward: 51.5
# Episode 99838, Reward: 52.5
# Episode 99839, Reward: 51.0
# Episode 99840, Reward: 53.0
# Episode 99841, Reward: 53.0
# Episode 99842, Reward: 53.0
# Episode 99843, Reward: 49.5
# Episode 99844, Reward: 52.0
# Episode 99845, Reward: 53.0
# Episode 99846, Reward: 51.0
# Episode 99847, Reward: 49.5
# Episode 99848, Reward: 52.0
# Episode 99849, Reward: 51.0
# Episode 99850, Reward: 53.0
# Episode 99851, Reward: 51.0
# Episode 99852, Reward: 50.5
# Episode 99853, Reward: 51.5
# Episode 99854, Reward: 51.5
# Episode 99855, Reward: 53.5
# Episode 99856, Reward: 52.5
# Episode 99857, Reward: 50.0
# Episode 99858, Reward: 51.5
# Episode 99859, Reward: 51.0
# Episode 99860, Reward: 54.0
# Episode 99861, Reward: 51.0
# Episode 99862, Reward: 53.5
# Episode 99863, Reward: 52.5
# Episode 99864, Reward: 52.0
# Episode 99865, Reward: 50.0
# Episode 99866, Reward: 52.5
# Episode 99867, Reward: 50.5
# Episode 99868, Reward: 51.5
# Episode 99869, Reward: 51.0
# Episode 99870, Reward: 53.0
# Episode 99871, Reward: 50.5
# Episode 99872, Reward: 54.0
# Episode 99873, Reward: 52.0
# Episode 99874, Reward: 51.5
# Episode 99875, Reward: 49.5
# Episode 99876, Reward: 52.5
# Episode 99877, Reward: 52.0
# Episode 99878, Reward: 53.0
# Episode 99879, Reward: 51.0
# Episode 99880, Reward: 52.0
# Episode 99881, Reward: 51.5
# Episode 99882, Reward: 51.0
# Episode 99883, Reward: 50.0
# Episode 99884, Reward: 53.5
# Episode 99885, Reward: 52.0
# Episode 99886, Reward: 50.0
# Episode 99887, Reward: 50.5
# Episode 99888, Reward: 53.0
# Episode 99889, Reward: 50.5
# Episode 99890, Reward: 49.5
# Episode 99891, Reward: 51.0
# Episode 99892, Reward: 49.5
# Episode 99893, Reward: 53.5
# Episode 99894, Reward: 54.0
# Episode 99895, Reward: 52.0
# Episode 99896, Reward: 51.5
# Episode 99897, Reward: 54.0
# Episode 99898, Reward: 51.0
# Episode 99899, Reward: 52.0
# Episode 99900, Reward: 52.0
# Episode 99901, Reward: 53.5
# Episode 99902, Reward: 50.5
# Episode 99903, Reward: 50.0
# Episode 99904, Reward: 52.0
# Episode 99905, Reward: 53.0
# Episode 99906, Reward: 51.0
# Episode 99907, Reward: 49.5
# Episode 99908, Reward: 51.5
# Episode 99909, Reward: 49.5
# Episode 99910, Reward: 52.5
# Episode 99911, Reward: 52.5
# Episode 99912, Reward: 53.5
# Episode 99913, Reward: 54.5
# Episode 99914, Reward: 53.5
# Episode 99915, Reward: 50.5
# Episode 99916, Reward: 49.5
# Episode 99917, Reward: 52.0
# Episode 99918, Reward: 53.0
# Episode 99919, Reward: 51.5
# Episode 99920, Reward: 51.0
# Episode 99921, Reward: 50.5
# Episode 99922, Reward: 53.5
# Episode 99923, Reward: 51.0
# Episode 99924, Reward: 53.0
# Episode 99925, Reward: 49.5
# Episode 99926, Reward: 51.0
# Episode 99927, Reward: 50.5
# Episode 99928, Reward: 50.5
# Episode 99929, Reward: 50.0
# Episode 99930, Reward: 52.5
# Episode 99931, Reward: 53.5
# Episode 99932, Reward: 51.5
# Episode 99933, Reward: 49.0
# Episode 99934, Reward: 51.0
# Episode 99935, Reward: 54.0
# Episode 99936, Reward: 51.0
# Episode 99937, Reward: 52.0
# Episode 99938, Reward: 50.0
# Episode 99939, Reward: 53.0
# Episode 99940, Reward: 53.0
# Episode 99941, Reward: 53.0
# Episode 99942, Reward: 51.5
# Episode 99943, Reward: 51.0
# Episode 99944, Reward: 50.5
# Episode 99945, Reward: 49.0
# Episode 99946, Reward: 49.5
# Episode 99947, Reward: 54.0
# Episode 99948, Reward: 53.0
# Episode 99949, Reward: 53.0
# Episode 99950, Reward: 50.0
# Episode 99951, Reward: 50.0
# Episode 99952, Reward: 52.0
# Episode 99953, Reward: 53.0
# Episode 99954, Reward: 50.5
# Episode 99955, Reward: 52.5
# Episode 99956, Reward: 50.5
# Episode 99957, Reward: 50.0
# Episode 99958, Reward: 50.5
# Episode 99959, Reward: 51.5
# Episode 99960, Reward: 52.5
# Episode 99961, Reward: 52.0
# Episode 99962, Reward: 54.0
# Episode 99963, Reward: 54.0
# Episode 99964, Reward: 52.5
# Episode 99965, Reward: 50.5
# Episode 99966, Reward: 53.5
# Episode 99967, Reward: 50.5
# Episode 99968, Reward: 50.0
# Episode 99969, Reward: 50.5
# Episode 99970, Reward: 51.0
# Episode 99971, Reward: 50.0
# Episode 99972, Reward: 50.5
# Episode 99973, Reward: 53.0
# Episode 99974, Reward: 54.0
# Episode 99975, Reward: 49.0
# Episode 99976, Reward: 54.5
# Episode 99977, Reward: 51.5
# Episode 99978, Reward: 53.0
# Episode 99979, Reward: 51.0
# Episode 99980, Reward: 50.5
# Episode 99981, Reward: 53.0
# Episode 99982, Reward: 52.0
# Episode 99983, Reward: 52.0
# Episode 99984, Reward: 52.0
# Episode 99985, Reward: 52.0
# Episode 99986, Reward: 49.0
# Episode 99987, Reward: 53.5
# Episode 99988, Reward: 50.0
# Episode 99989, Reward: 49.5
# Episode 99990, Reward: 52.0
# Episode 99991, Reward: 50.5
# Episode 99992, Reward: 50.5
# Episode 99993, Reward: 52.5
# Episode 99994, Reward: 54.0
# Episode 99995, Reward: 54.0
# Episode 99996, Reward: 51.5
# Episode 99997, Reward: 51.0
# Episode 99998, Reward: 52.5
# Episode 99999, Reward: 51.0
# Episode 100000, Reward: 50.0

# %%
get_info(beater_optimal_policy, cook_optimal_policy)
# Out:
# +-------+-------------------+-----------------+
# | STATE | BEATER OPT POLICY | COOK OPT POLICY |
# +-------+-------------------+-----------------+
# | 1     | D                 | D               |
# | 2     | D                 | D               |
# | 3     | D                 | D               |
# | 4     | L                 | L               |
# | 5     | D                 | D               |
# | 6     | R                 | R               |
# | 7     | D                 | D               |
# | 8     | R                 | R               |
# | 9     | R                 | R               |
# | 10    | R                 | R               |
# | 11    | R                 | R               |
# | 12    | TR                | TR              |
# | 13    | D                 | D               |
# | 14    | L                 | L               |
# | 15    | D                 | D               |
# | 16    | R                 | R               |
# | 17    | R                 | R               |
# | 18    | R                 | R               |
# | 19    | U                 | U               |
# | 20    | L                 | L               |
# | 21    | U                 | U               |
# | 22    | U                 | U               |
# | 23    | D                 | D               |
# | 24    | D                 | D               |
# | 25    | R                 | R               |
# | 26    | U                 | U               |
# | 27    | R                 | R               |
# | 28    | D                 | D               |
# | 29    | L                 | L               |
# | 30    | U                 | U               |
# | 31    | L                 | L               |
# | 32    | L                 | L               |
# +-------+-------------------+-----------------+

# %%
get_optimal_policy_matrix(beater_optimal_policy)
# Out:
# Optimal Policy Matrix 1:
# [['→' '→' '→' '↓']
#  ['⤴' '→' '→' '↓']
#  ['↑' '←' '←' '⇒']
#  ['→' '→' '→' '↑']]
#
# Optimal Policy Matrix 2:
# [['→' '↓' 'C' '←']
#  ['→' '↓' '⤴' '←']
#  ['→' '↓' '↑' '←']
#  ['→' '→' '→' '↑']]

# %%
get_optimal_policy_matrix(cook_optimal_policy)
# Out:
# Optimal Policy Matrix 1:
# [['↓' '↓' '↓' '←']
#  ['↓' '→' '↓' '→']
#  ['→' '→' '→' '⇒']
#  ['↓' '←' '↓' '→']]
#
# Optimal Policy Matrix 2:
# [['→' '→' 'C' '←']
#  ['↑' '↑' '↓' '↓']
#  ['→' '↑' '→' '↓']
#  ['←' '↑' '←' '←']]
